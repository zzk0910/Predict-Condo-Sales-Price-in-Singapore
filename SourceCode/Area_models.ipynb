# %%
# Import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import training dataset

data_type = {
            'listing_id': int,
            'name': str,
             'street': str,
             'type': str,
             'model': str,
             'market_segment': str,
             'type_of_area': str,
             'bedrooms': str,
             'bathrooms': float,
             'district': int,
             'region': str,
             'planning_area': str,
             'subszone': str,
             'lat': float,
             'lng': float,
             'tenure': str,
             'built_year': float,
             'no_of_units': float,
             'area_size': float,
             'eco_category': str,
             'accessibility': str,
             'date_listed': str,
             'price': int}

train_set = pd.read_csv("Data/train.csv", dtype=data_type)


# Make a copy
train_set_copy = train_set.copy()

# %% [markdown]
# # New Section

# %%
# Take a glance on dataset
train_set_copy.head(5)
# Out:
#    listing_id                  name             street         type  \
# 0     6998418              seascape       57 cove way   condominium
# 1     2046604             la maison  10 moulmein rise     apartment
# 2     7563513                  viva    2 suffolk walk   condominium
# 3     3071445       urban treasures   205 jalan eunos   condominium
# 4     9667539  infini at east coast    east coast road    apartment
#
#          model market_segment type_of_area bedrooms  bathrooms  district  ...  \
# 0  condominium            ocr       strata        3        4.0         4  ...
# 1    apartment            ocr       strata        3        3.0        11  ...
# 2  condominium            ocr       strata        4        3.0        11  ...
# 3  condominium            ocr       strata        3        2.0        14  ...
# 4    apartment            ocr       strata        3        3.0        15  ...
#
#         lat         lng              tenure  built_year  no_of_units  \
# 0  1.239337  103.837487  leasehold/99 years      2011.0        151.0
# 1  1.319533  103.847030            freehold      1999.0         24.0
# 2  1.315656  103.844445            freehold      2012.0        235.0
# 3  1.329367  103.905791            freehold         NaN        237.0
# 4  1.309176  103.911352            freehold         NaN         36.0
#
#   area_size   eco_category  accessibility  date_listed    price
# 0    2336.0  uncategorized        guarded   2021-05-04  5390000
# 1    1259.0  uncategorized        guarded   2021-05-07  2310000
# 2    1959.0  uncategorized        guarded   2021-06-30  5279500
# 3     883.0  uncategorized        guarded   2022-01-02  1843600
# 4    1066.0  uncategorized        guarded   2021-12-24  2262700
#
# [5 rows x 23 columns]

# %%
# Check nan for each column
for col_name, _ in train_set_copy.iteritems():
    if len(train_set_copy[train_set_copy[col_name].isna()])>0:
        print("%s: %s rows" % (col_name, len(train_set_copy[train_set_copy[col_name].isna()])))
# Out:
# model: 1280 rows
# bedrooms: 404 rows
# bathrooms: 1236 rows
# tenure: 287 rows
# built_year: 10043 rows
# no_of_units: 1042 rows
# area_size: 2 rows

# %%
# Deal with NaN data

#transformaing bedrooms, i.e: from 2+1 to 3
train_set_copy['bedrooms']=train_set_copy['bedrooms'].apply(lambda x: x if type(x)==float else eval(x))

# Get median for three columns: bathrooms, built_year, no_of_units
bedroom_median = np.median(train_set_copy['bedrooms'].dropna())
bathroom_median = np.median(train_set_copy['bathrooms'].dropna())
built_year_median = np.median(train_set_copy['built_year'].dropna())
no_of_units_median = np.median(train_set_copy['no_of_units'].dropna())

print("bedroom_median: ", bedroom_median)
print("bathroom_median: ", bathroom_median)
print("built_year_median: ", built_year_median)
print("no_of_units_median: ", no_of_units_median)

train_set_copy['bedrooms'].fillna(value=bedroom_median, inplace=True)
train_set_copy['bathrooms'].fillna(value=bathroom_median, inplace=True)
train_set_copy['built_year'].fillna(value=built_year_median, inplace=True)
train_set_copy['no_of_units'].fillna(value=no_of_units_median, inplace=True)

# Check column 'tenure', treat houses that are not 'freehold' as 'leasehold', also fill NaN with 'leasehold'
train_set_copy['tenure'].where(train_set_copy['tenure']=='freehold', other='leasehold', inplace=True)

# Drop rows whose area_size is NaN
train_set_copy.dropna(axis=0, subset=['area_size'], inplace=True)
# Out:
# bedroom_median:  3.0
# bathroom_median:  2.0
# built_year_median:  2014.0
# no_of_units_median:  366.0

# %%
# Convert some string columns to 0-1 verctors

# Type
type_mapping = {'apartment': 0 ,'condominium' : 1}
train_set_copy['type'] = train_set_copy['type'].map(type_mapping)

# Tenure
tenure_mapping = {'freehold':0 ,'leasehold' : 1}
train_set_copy['tenure'] = train_set_copy['tenure'].map(tenure_mapping)


# For 'build_year', use 2022 - original year to get current age of houses
train_set_copy['built_year'] = 2022 - train_set_copy['built_year']

# For no_of_units, divide all houses into 10 categories, manually set lowest limit=0 and highest limit=10000
cut_bins = np.zeros(shape=(11,))
cut_bins = np.quantile(train_set_copy['no_of_units'], [0.1*i for i in range(11)])
cut_labels = [(cut_bins[i] + cut_bins[i+1])/2 for i in range(10)]
cut_bins[0], cut_bins[-1] = 0, 10000000
train_set_copy['no_of_units'] = pd.cut(train_set_copy['no_of_units'], bins=cut_bins, labels=cut_labels, include_lowest=True).values

# Convert name, street, region and planning area to numerical values
name_mapping = {label:idx for idx,label in enumerate(set(train_set_copy['name']))}
street_mapping = {label:idx for idx,label in enumerate(set(train_set_copy['street']))}
region_mapping = {'north-east region': 0,
                 'north region': 1,
                 'west region': 2,
                 'east region': 3,
                 'central region': 4}
planning_area_mapping = {label:idx for idx,label in enumerate(set(train_set_copy['planning_area']))}

train_set_copy['name'] = train_set_copy['name'].map(name_mapping)
train_set_copy['street'] = train_set_copy['street'].map(street_mapping)
train_set_copy['region'] = train_set_copy['region'].map(region_mapping)
train_set_copy['planning_area'] = train_set_copy['planning_area'].map(planning_area_mapping)

# %%
# Take a glance of dataset after data preprocessing
train_set_copy.reset_index(drop=True, inplace=True)
train_set_copy.head(3)
# Out:
#    listing_id  name  street  type        model market_segment type_of_area  \
# 0     6998418  1425    3246     1  condominium            ocr       strata
# 1     2046604   395    1183     0    apartment            ocr       strata
# 2     7563513   650     461     1  condominium            ocr       strata
#
#    bedrooms  bathrooms  district  ...       lat         lng tenure  \
# 0       3.0        4.0         4  ...  1.239337  103.837487      1
# 1       3.0        3.0        11  ...  1.319533  103.847030      0
# 2       4.0        3.0        11  ...  1.315656  103.844445      0
#
#    built_year  no_of_units  area_size   eco_category accessibility  \
# 0        11.0        138.5     2336.0  uncategorized       guarded
# 1        23.0         28.5     1259.0  uncategorized       guarded
# 2        10.0        217.0     1959.0  uncategorized       guarded
#
#    date_listed    price
# 0   2021-05-04  5390000
# 1   2021-05-07  2310000
# 2   2021-06-30  5279500
#
# [3 rows x 23 columns]

# %%
# Check correlation between 'price' and other columns
print(train_set_copy.corr(method='pearson')['price'])
# Out:
# listing_id      -0.000812
# name            -0.020001
# street          -0.002011
# type             0.017215
# bedrooms         0.430928
# bathrooms        0.523360
# district        -0.219530
# region           0.196188
# planning_area    0.052380
# lat             -0.233974
# lng             -0.066018
# tenure          -0.126546
# built_year       0.008851
# area_size        0.869712
# price            1.000000
# Name: price, dtype: float64

# %%
for col_name in ['district', 'region']:
    print("Column name: %s" % (col_name))
    
    # Box plot
    train_set_copy.boxplot(column='price', by=col_name)
    plt.show()
# Out:
# Column name: district
# Column name: region

# %%
# Import auxiliary data
commercial_centres = pd.read_csv("Data/auxiliary-data/sg-commerical-centres.csv")
hawker_centres = pd.read_csv("Data/auxiliary-data/sg-gov-markets-hawker-centres.csv")
primary_schools = pd.read_csv("Data/auxiliary-data/sg-primary-schools.csv")
secondary_schools = pd.read_csv("Data/auxiliary-data/sg-secondary-schools.csv")
shopping_malls = pd.read_csv("Data/auxiliary-data/sg-shopping-malls.csv")
stations = pd.read_csv("Data/auxiliary-data/sg-train-stations.csv")

# %%
# Calculate distance in km with lat & lng
def haversine_batch(train_lng, train_lat, place_lng, place_lat):  # lng1，lat1，lng2，lat2
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    """

    place_lat = np.radians(place_lat)
    place_lng = np.radians(place_lng)

    train_lat = np.radians(train_lat)
    train_lng = np.radians(train_lng)

    dlat = place_lat - train_lat
    dlng = place_lng - train_lng

    a = np.sin(dlat / 2) ** 2 + np.cos(train_lat) * np.cos(place_lat) * np.sin(dlng / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371 # Radius of the earth in km
    return c * r


def cal_distance(X, is_train: bool):
    # Find distance to nearest facilities for each house
    facilities = [commercial_centres, hawker_centres, primary_schools, secondary_schools, shopping_malls, stations]

    res = []

    for f in facilities:

        distance = np.full((len(X), 1), np.inf)

        for _, row in f.iterrows():
            d = haversine_batch(X['lng'].values, X['lat'].values, row['lng'], row['lat']).reshape(-1, 1)
            distance = np.minimum(distance, d)
        
        res.append(distance)
        
    if is_train:
        res.append(X['price'].values.reshape(-1, 1))
        pd_distance = pd.DataFrame(data=np.squeeze(np.asarray(res)).swapaxes(0, 1),
                              columns=['to_commercial_centres', 'to_hawker_centres', 'to_primary_schools',
                                       'to_secondary_schools', 'to_shopping_malls', 'to_train_stations', 'price'])
    else:
        pd_distance = pd.DataFrame(data=np.squeeze(np.asarray(res)).swapaxes(0, 1),
                          columns=['to_commercial_centres', 'to_hawker_centres', 'to_primary_schools',
                                   'to_secondary_schools', 'to_shopping_malls', 'to_train_stations'])
    return pd_distance

# %%
# Find distance
train_distance = cal_distance(train_set_copy, is_train=True)
# Discover correlations between price to each other parameter
print(train_distance.corr(method='pearson')['price'])
# Out:
# to_commercial_centres    0.020541
# to_hawker_centres        0.006066
# to_primary_schools       0.189241
# to_secondary_schools     0.196791
# to_shopping_malls       -0.061559
# to_train_stations        0.020612
# price                    1.000000
# Name: price, dtype: float64

# %%
# Show pd_distance
train_distance.reset_index(drop=True, inplace=True)
train_distance.head(3)
# Out:
#    to_commercial_centres  to_hawker_centres  to_primary_schools  \
# 0               5.604095           4.079855            4.064895
# 1               0.407610           0.519457            0.235428
# 2               0.498692           0.648320            0.294793
#
#    to_secondary_schools  to_shopping_malls  to_train_stations      price
# 0              4.429845           3.218556           3.409821  5390000.0
# 1              1.263926           0.339015           0.370228  2310000.0
# 2              1.075413           0.201332           0.536424  5279500.0

# %%
# Option 1: train dataset without "distance" information
# X_train_without_auxiliary_data = train_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'lat', 'lng', 'tenure', 'built_year', 'no_of_units', 'area_size']]
train_without_auxiliary_data = train_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'tenure', 'built_year', 'no_of_units', 'area_size', 'price']]
train_without_auxiliary_data.head(5)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       3.0        4.0         4       1        11.0       138.5
# 1     0       3.0        3.0        11       0        23.0        28.5
# 2     1       4.0        3.0        11       0        10.0       217.0
# 3     1       3.0        2.0        14       0         8.0       217.0
# 4     0       3.0        3.0        15       0         8.0        28.5
#
#    area_size    price
# 0     2336.0  5390000
# 1     1259.0  2310000
# 2     1959.0  5279500
# 3      883.0  1843600
# 4     1066.0  2262700

# %%
# Option 2: train dataset with "distance" information (Defualt choice)
train_plus_auxiliary_data = pd.concat([train_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'tenure', 'built_year', 'no_of_units', 'area_size']], train_distance.iloc[:, :-1], train_set_copy['price']], axis=1)
# X_train_plus_auxiliary_data = pd.concat([X_train_without_auxiliary_data, train_distance[['to_primary_schools', 'to_secondary_schools']]], axis=1)
train_plus_auxiliary_data.head(5)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       3.0        4.0         4       1        11.0       138.5
# 1     0       3.0        3.0        11       0        23.0        28.5
# 2     1       4.0        3.0        11       0        10.0       217.0
# 3     1       3.0        2.0        14       0         8.0       217.0
# 4     0       3.0        3.0        15       0         8.0        28.5
#
#    area_size  to_commercial_centres  to_hawker_centres  to_primary_schools  \
# 0     2336.0               5.604095           4.079855            4.064895
# 1     1259.0               0.407610           0.519457            0.235428
# 2     1959.0               0.498692           0.648320            0.294793
# 3      883.0               1.848952           1.018186            0.483431
# 4     1066.0               2.221947           0.618976            0.376927
#
#    to_secondary_schools  to_shopping_malls  to_train_stations    price
# 0              4.429845           3.218556           3.409821  5390000
# 1              1.263926           0.339015           0.370228  2310000
# 2              1.075413           0.201332           0.536424  5279500
# 3              0.495752           1.684204           0.689663  1843600
# 4              0.624355           0.822088           1.330838  2262700

# %%
all_data = train_plus_auxiliary_data
area_split_points = [0, 500, 750, 1000, 1200, 1500, 2000, 2500, 3000, 4000, 5000, 7500, 10000]
print("Data distribution:")
# Area
# 0~500
area_set_0 = all_data[(all_data['area_size'] >= area_split_points[0])&(all_data['area_size'] < area_split_points[1])]
print("0~500: ", len(area_set_0))
# 500~750
area_set_1 = all_data[(all_data['area_size'] >= area_split_points[1])&(all_data['area_size'] < area_split_points[2])]
print("500~750: ", len(area_set_1))
# 750~1000
area_set_2 = all_data[(all_data['area_size'] >= area_split_points[2])&(all_data['area_size'] < area_split_points[3])]
print("750~1000: ", len(area_set_2))
# 1000~1200
area_set_3 = all_data[(all_data['area_size'] >= area_split_points[3])&(all_data['area_size'] < area_split_points[4])]
print("1000~1200: ", len(area_set_3))
# 1200~1500
area_set_4 = all_data[(all_data['area_size'] >= area_split_points[4])&(all_data['area_size'] < area_split_points[5])]
print("1200~1500: ", len(area_set_4))
# 1500~2000
area_set_5 = all_data[(all_data['area_size'] >= area_split_points[5])&(all_data['area_size'] < area_split_points[6])]
print("1500~2000: ", len(area_set_5))
# 2000~2500
area_set_6 = all_data[(all_data['area_size'] >= area_split_points[6])&(all_data['area_size'] < area_split_points[7])]
print("2000~2500: ", len(area_set_6))
# 2500~3000
area_set_7 = all_data[(all_data['area_size'] >= area_split_points[7])&(all_data['area_size'] < area_split_points[8])]
print("2500~3000: ", len(area_set_7))
# 3000~4000
area_set_8 = all_data[(all_data['area_size'] >= area_split_points[8])&(all_data['area_size'] < area_split_points[9])]
print("3000~4000: ", len(area_set_8))
# 4000~5000
area_set_9 = all_data[(all_data['area_size'] >= area_split_points[9])&(all_data['area_size'] < area_split_points[10])]
print("4000~5000: ", len(area_set_9))
# 5000~7500
area_set_10 = all_data[(all_data['area_size'] >= area_split_points[10])&(all_data['area_size'] < area_split_points[11])]
print("5000~7500: ", len(area_set_10))
# 7500~10000
area_set_11 = all_data[(all_data['area_size'] >= area_split_points[11])&(all_data['area_size'] < area_split_points[12])]
print("7500~10000: ", len(area_set_11))
# 10000~INF
area_set_12 = all_data[all_data['area_size'] >= area_split_points[-1]]
print("10000~INF: ", len(area_set_12))
# Out:
# Data distribution:
# 0~500:  2218
# 500~750:  6286
# 750~1000:  5282
# 1000~1200:  3324
# 1200~1500:  3527
# 1500~2000:  2294
# 2000~2500:  1147
# 2500~3000:  662
# 3000~4000:  625
# 4000~5000:  246
# 5000~7500:  331
# 7500~10000:  77
# 10000~INF:  27

# %% [markdown]
# # Model Training

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.preprocessing import StandardScaler
import joblib
import xgboost as xgb
import lightgbm as lgb

# %matplotlib inline

# %%
area_train_list = [area_set_0, area_set_1, area_set_2, area_set_3, area_set_4, area_set_5, area_set_6,
               area_set_7, area_set_8, area_set_9, area_set_10, area_set_11, area_set_12]

# %% [markdown]
# ## GBDT

# %%
class GBDT_model():
    def __init__(self, **kwargs):
        self.loss = kwargs.get('loss', 'ls')
        self.learning_rate = kwargs.get('learning_rate', 0.15)
        self.subsample = kwargs.get('subsample', 1.0)
        self.max_depth = kwargs.get('max_depth', 2)
        self.n_estimators = kwargs.get('n_estimators', 150)
        self.max_leaf_nodes = kwargs.get('max_leaf_nodes', None)
        self.min_samples_leaf = kwargs.get('min_samples_leaf', 3)
        self.min_samples_split = kwargs.get('min_samples_split', 5)
        self.alpha = kwargs.get('alpha', 0.9)

    def opt_hyper_grid(self, x, y, param_space, num_sets: int=5):

        print('Finding best hyper-parameters for the model...')
        estimator = GradientBoostingRegressor(loss=self.loss, learning_rate=self.learning_rate,
                                              subsample=self.subsample, max_depth=self.max_depth,
                                              n_estimators=self.n_estimators,
                                              max_leaf_nodes=self.max_leaf_nodes,
                                              min_samples_leaf=self.min_samples_leaf,
                                              min_samples_split=self.min_samples_split,
                                              alpha=self.alpha)
        # Cross-validation
        gbdt = GridSearchCV(estimator=estimator, 
                            param_grid=param_space, 
                            cv=KFold(n_splits=num_sets, shuffle=True), 
                            scoring='neg_root_mean_squared_error')
        grid_result = gbdt.fit(x, y)

        means = grid_result.cv_results_['mean_test_score']
        params = grid_result.cv_results_['params']

        for mean, param in zip(means, params):
            print("%f  with:   %r" % (mean, param))

        best_params = gbdt.best_params_
        print('Best params set:', best_params)
        print('Minimum root mean squared error:', -np.max(means))
        print('---------------------------------------------------')
        
        self.learning_rate = best_params.get('learning_rate', self.learning_rate)
        self.max_depth = best_params.get('max_depth', self.max_depth)
        self.subsample = best_params.get('subsample', self.subsample)
        self.n_estimators = best_params.get('n_estimators', self.n_estimators)
        self.max_leaf_nodes = best_params.get('max_leaf_nodes', self.max_leaf_nodes)
        self.min_samples_leaf = best_params.get('min_samples_leaf', self.min_samples_leaf)
        self.min_samples_split = best_params.get('min_samples_split', self.min_samples_split)
        self.alpha = best_params.get('alpha', self.alpha)

        return 


    def build_model(self, x, y, params, grid_search: bool = True):
        """
        If use grid search, then each parameter can have multiple values
        
        Example: params = {'learning_rate': [0.1, 0.3],
                           'n_estimators': [100, 200, 300]
                           }
                           
        If do not use grid search, then each parameter should have only one value
        
        Example: params = {'learning_rate': 0.1,
                           'n_estimators': 100
                          }
        
        """
        
        
        if grid_search:
            self.opt_hyper_grid(x, y, params)
        else:

            self.learning_rate = params.get('learning_rate', self.learning_rate)
            self.max_depth = params.get('max_depth', self.max_depth)
            self.subsample = params.get('subsample', self.subsample)
            self.n_estimators = params.get('n_estimators', self.n_estimators)
            self.max_leaf_nodes = params.get('max_leaf_nodes', self.max_leaf_nodes)
            self.min_samples_leaf = params.get('min_samples_leaf', self.min_samples_leaf)
            self.min_samples_split = params.get('min_samples_split', self.min_samples_split)
            self.alpha = params.get('alpha', self.alpha)

        gbdt = GradientBoostingRegressor(loss=self.loss, learning_rate=self.learning_rate,
                                         subsample=self.subsample, max_depth=self.max_depth,
                                         n_estimators=self.n_estimators,
                                         max_leaf_nodes=self.max_leaf_nodes,
                                         min_samples_leaf=self.min_samples_leaf,
                                         min_samples_split=self.min_samples_split, alpha=self.alpha)
        # 10-folder cross-validation
        sk = KFold(n_splits=10, shuffle=True)
        scores_train = list()
        scores_val = list()
        for train_ind, val_ind in sk.split(x, y):
            train_x = x.iloc[train_ind].values
            train_y = y.iloc[train_ind]
            val_x = x.iloc[val_ind].values
            val_y = y.iloc[val_ind]

            gbdt.fit(train_x, train_y)
            pred_train_gbdt = gbdt.predict(train_x)
            pred_val_gbdt = gbdt.predict(val_x)

            score_train = mean_squared_error(train_y, pred_train_gbdt, squared=False)
            scores_train.append(score_train)
            score_val = mean_squared_error(val_y, pred_val_gbdt, squared=False)
            scores_val.append(score_val)

        print('Train root mean squared error:', np.mean(scores_train))
        print('Val root mean squared error:', np.mean(scores_val))

        return gbdt, np.mean(scores_train), np.mean(scores_val)

# %%
# Grid search hyperparameters for each model

train_error = 0
val_error = 0
save_model = True

for i in range(len(area_train_list)):
    print("=========== Set %d ===========" % i)
    samples_weight = len(area_train_list[i]) / len(train_set_copy)
    X_train = area_train_list[i].iloc[:, :-1]
    Y_train = area_train_list[i].iloc[:, -1]
    
    task = GBDT_model()

    params = {
        'learning_rate': [0.3, 0.45, 0.55],
        'max_depth': [2, 3, 4],
        'min_samples_leaf': [10, 50, 120],
        'n_estimators': [200, 350, 500]

    }

    gbdt_reg, scores_train, scores_val = task.build_model(X_train, Y_train, params, grid_search=True)
    if save_model:
        save_path = "Models/Area_models/gbdt_area_" + str(i) + ".pkl"
        joblib.dump(gbdt_reg, save_path)

    print("Weight: %.3f" % samples_weight)
    train_error += scores_train * samples_weight
    val_error += scores_val * samples_weight

print("*" * 30)
print("Overall train root mean squared error: %.10f" % train_error)
print("Overall val root mean squared error: %.10f" % val_error)
# Out:
# =========== Set 0 ===========
# Finding best hyper-parameters for the model...
# -105517.181111  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -104205.681279  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -104972.694511  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -107349.627603  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -105163.780056  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -104732.815838  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -112315.927517  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -108778.725454  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -106609.459780  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -104067.642607  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -105644.278172  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -106138.173288  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -103473.484822  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -103760.305808  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -104640.316421  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -105376.840316  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -103941.739456  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -103511.029451  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -107982.596534  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -109202.606313  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -110119.930798  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -102143.951527  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -103518.546315  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -104580.852532  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -103506.270497  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -102596.811986  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -102702.718991  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# -106313.033494  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -106436.967609  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -107763.668809  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -106691.239020  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -105665.024928  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -105930.034364  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -108674.969748  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -105722.651986  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -104645.242625  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -108464.176314  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -109504.933953  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -110435.436727  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -104974.506931  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -105801.299724  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -106954.786755  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -104449.019729  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -103461.768060  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -103158.364345  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -108402.664513  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -109501.330890  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -110452.018814  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -104794.553980  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -106260.609786  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -107003.232741  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -102088.003869  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -102118.071559  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -102697.147080  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# -106318.466161  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -106119.299799  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -107053.090431  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -107184.313479  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -106395.388581  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -106699.046117  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -108800.212688  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -106283.467232  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -105499.791692  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -109734.710030  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -110957.373300  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -111546.619029  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -106176.042564  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -107549.248913  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -108459.488783  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -104155.938392  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -103455.539985  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -103452.215861  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -112547.974305  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -113663.271850  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -114436.403924  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -107434.243893  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -108809.425262  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -109472.179261  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -102882.073176  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -104041.720910  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -104696.361216  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# Minimum root mean squared error: 102088.00386852023
# ---------------------------------------------------
# Train root mean squared error: 78656.00914586116
# Val root mean squared error: 100884.3981039607
# Weight: 0.085
# =========== Set 1 ===========
# Finding best hyper-parameters for the model...
# -191109.258446  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -184773.167558  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -181742.540301  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -194264.984349  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -188093.648920  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -185393.344760  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -192836.241205  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -187034.531066  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -184618.881749  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -178843.765131  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -176985.578995  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -175819.455097  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -183987.082988  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -184611.649987  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -185444.042153  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -182809.713913  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -182180.258449  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -182490.323777  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -178585.154274  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -179191.453160  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -179538.670276  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -183464.507076  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -186468.881948  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -187714.138024  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -178917.919759  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -179746.459127  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -181974.092454  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# -189051.748578  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -183315.782692  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -180889.396790  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -190908.355969  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
#
with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -17511043.670407  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -17511043.670407  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -17511043.670407  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -17511043.670407  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -17511043.670407  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -17511043.670407  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# Minimum root mean squared error: 5041863.858539155
# ---------------------------------------------------
# Train root mean squared error: 1267231.2809076116
# Val root mean squared error: 6703824.383758219
# Weight: 0.003
# =========== Set 12 ===========
# Finding best hyper-parameters for the model...
# -16776943.246409  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -16183895.023866  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15969737.457176  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16776943.246409  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -16183895.023866  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15969737.457176  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16776943.246409  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -16183895.023866  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15969737.457176  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16243748.918643  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -15890848.677555  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15712181.893429  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16243748.918643  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -15890848.677555  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15712181.893429  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16243748.918643  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -15890848.677555  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15712181.893429  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.45, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16061861.542337  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# -15769961.748062  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15601591.829598  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16061861.542337  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 200}
# -15769961.748062  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15601591.829598  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 3, 'min_samples_leaf': 120, 'n_estimators': 500}
# -16061861.542337  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# -15769961.748062  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 350}
# -15601591.829598  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 200}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 350}
# -18847098.404921  with:   {'learning_rate': 0.55, 'max_depth': 4, 'min_samples_leaf': 120, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.55, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# Minimum root mean squared error: 15601591.82959787
# ---------------------------------------------------
# Train root mean squared error: 3951670.932961824
# Val root mean squared error: 15845195.923777122
# Weight: 0.001
# ******************************
# Overall train root mean squared error: 177747.6567172899
# Overall val root mean squared error: 366283.9763949016

# %%
# Fine tune model for a specific training subset

save_model = False
training_set = 0     # Choose from 0~12
X_train = area_train_list[training_set].iloc[:, :-1]
Y_train = area_train_list[training_set].iloc[:, -1]
samples_weight = len(area_train_list[training_set]) / len(train_set_copy)

task = GBDT_model()

params = {'learning_rate': 0.5, 
          'max_depth': 7,
          'min_samples_leaf': 70,
          'n_estimators': 500
         }

gbdt_reg, _, _ = task.build_model(X_train, Y_train, params, grid_search=False)

if save_model:
    save_path = "Models/Area_models/gbdt_area_" + str(training_set) + ".pkl"
    joblib.dump(gbdt_reg, save_path)

print("Weight: %.3f" % samples_weight)
# Out:
# Train root mean squared error: 50817.14769543944
# Val root mean squared error: 102556.34410069764
# Weight: 0.085

# %% [markdown]
# ## Xgboost

# %%
class XGBoost_model():
    def __init__(self, **kwargs):
        self.objective = kwargs.get('objective', 'reg:squarederror')
        self.learning_rate = kwargs.get('learning_rate', 0.15)
        self.subsample = kwargs.get('subsample', 1.0)
        self.max_depth = kwargs.get('max_depth', 3)
        self.n_estimators = kwargs.get('n_estimators', 150)
        self.booster = kwargs.get('booster', 'gbtree')
        self.gamma = kwargs.get('gamma', 0)
        self.reg_alpha = kwargs.get('reg_alpha', 0)
        self.reg_lambda = kwargs.get('reg_lambda', 1)

    def opt_hyper_grid(self, x, y, param_space, num_sets: int=5):

        print('Finding best hyper-parameters for the model...')
        estimator = xgb.XGBRegressor(objective=self.objective, max_depth=self.max_depth,
                                     learning_rate=self.learning_rate, n_estimators=self.n_estimators,
                                     subsample=self.subsample, booster=self.booster, n_jobs=-1, gamma=self.gamma,
                                     reg_alpha=self.reg_alpha, reg_lambda=self.reg_lambda)
        xgb_try = GridSearchCV(estimator=estimator, param_grid=param_space, cv=KFold(n_splits=num_sets, shuffle=True), scoring='neg_root_mean_squared_error')
        grid_result = xgb_try.fit(x, y)

        means = grid_result.cv_results_['mean_test_score']
        params = grid_result.cv_results_['params']
        
        for mean, param in zip(means, params):
            print("%f  with:   %r" % (mean, param))

        best_params = xgb_try.best_params_
        print('Best params set:', best_params)
        print('Minimum root mean squared error: ', -np.max(means))
        print('---------------------------------------------------')
        
        self.learning_rate = best_params.get('learning_rate', self.learning_rate)
        self.max_depth = best_params.get('max_depth', self.max_depth)
        self.subsample = best_params.get('subsample', self.subsample)
        self.n_estimators = best_params.get('n_estimators', self.n_estimators)
        self.booster = best_params.get('booster', self.booster)
        self.gamma = best_params.get('gamma', self.gamma)
        self.reg_alpha = best_params.get('reg_alpha', self.reg_alpha)
        self.reg_lambda = best_params.get('alpha', self.reg_lambda)

        return 


    def build_model(self, x, y, params, grid_search: bool = True):
        """
        If use grid search, then each parameter can have multiple values
        
        Example: params = {'learning_rate': [0.1, 0.3],
                           'n_estimators': [100, 200, 300]
                           }
                           
        If do not use grid search, then each parameter should have only one value
        
        Example: params = {'learning_rate': 0.1,
                           'n_estimators': 100
                          }
        
        """
        
        
        if grid_search:
            self.opt_hyper_grid(x, y, params)
        else:

            self.learning_rate = params.get('learning_rate', self.learning_rate)
            self.max_depth = params.get('max_depth', self.max_depth)
            self.subsample = params.get('subsample', self.subsample)
            self.n_estimators = params.get('n_estimators', self.n_estimators)
            self.booster = params.get('booster', self.booster)
            self.gamma = params.get('gamma', self.gamma)
            self.reg_alpha = params.get('reg_alpha', self.reg_alpha)
            self.reg_lambda = params.get('alpha', self.reg_lambda)

        xgb_reg = xgb.XGBRegressor(objective=self.objective, max_depth=self.max_depth,
                                   learning_rate=self.learning_rate, n_estimators=self.n_estimators,
                                   subsample=self.subsample, booster=self.booster, gamma=self.gamma,
                                   n_jobs=-1, reg_alpha=self.reg_alpha, reg_lambda=self.reg_lambda)
        
        # 10-folder cross-validation
        sk = KFold(n_splits=5, shuffle=True)
        scores_train = list()
        scores_val = list()
        for train_ind, val_ind in sk.split(x, y):
            train_x = x.iloc[train_ind].values
            train_y = y.iloc[train_ind]
            val_x = x.iloc[val_ind].values
            val_y = y.iloc[val_ind]

            xgb_reg.fit(train_x, train_y)
            pred_train_xgb = xgb_reg.predict(train_x)
            pred_val_xgb = xgb_reg.predict(val_x)

            score_train = mean_squared_error(train_y, pred_train_xgb, squared=False)
            scores_train.append(score_train)
            score_val = mean_squared_error(val_y, pred_val_xgb, squared=False)
            scores_val.append(score_val)

        print('Train root mean squared error:', np.mean(scores_train))
        print('Val root mean squared error:', np.mean(scores_val))

        return xgb_reg, np.mean(scores_train), np.mean(scores_val)

# %%
# Grid search hyperparameters for each model

train_error = 0
val_error = 0
save_model = True


for i in range(len(area_train_list)):
    print("=========== Set %d ===========" % i)
    samples_weight = len(area_train_list[i]) / len(train_set_copy)
    X_train = area_train_list[i].iloc[:, :-1]
    X_train['no_of_units'] = X_train['no_of_units'].astype('float32')
    Y_train = area_train_list[i].iloc[:, -1]
    
    task = XGBoost_model()

    params = {'learning_rate': [0.3, 0.45, 0.55, 0.7],
              'n_estimators': [150, 300, 500, 700],
              'max_depth':[3, 4, 5]

    }

    xgb_reg, scores_train, scores_val = task.build_model(X_train, Y_train, params, grid_search=True)
    if save_model:
        save_path = "Models/Area_models/xgboost_area_" + str(i) + ".pkl"
        joblib.dump(xgb_reg, save_path)

    print("Weight: %.3f" % samples_weight)
    train_error += scores_train * samples_weight
    val_error += scores_val * samples_weight

print("*" * 30)
print("Overall train root mean squared error: %.10f" % train_error)
print("Overall val root mean squared error: %.10f" % val_error)
# kaggle_X_test = X_test_plus_auxiliary_data
# Out:
# =========== Set 0 ===========
# Finding best hyper-parameters for the model...
# -103111.746983  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -102294.262637  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -101814.889712  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 500}
# -101946.709359  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 700}
# -106558.512800  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -106753.241104  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -107357.927662  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 500}
# -108038.991645  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 700}
# -101696.458400  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -102641.021664  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -103224.715958  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 500}
# -103325.310181  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 700}
# -103916.523381  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 150}
# -103125.966038  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 300}
# -103589.575874  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 500}
# -104061.256421  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 700}
# -107695.823487  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 150}
# -108543.734116  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 300}
# -109449.065484  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 500}
# -109773.227708  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 700}
# -106218.153743  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 150}
# -107112.275664  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 300}
# -107313.488674  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 500}
# -107340.840253  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 700}
# -106798.317341  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 150}
# -106664.025459  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 300}
# -107337.835864  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 500}
# -107950.844441  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 700}
# -106326.150082  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 150}
# -107346.109762  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 300}
# -108028.558877  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 500}
# -108213.133662  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 700}
# -110884.039618  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 150}
# -111353.708899  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 300}
# -111425.937737  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 500}
# -111434.525767  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 700}
# -112591.925912  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -112305.085227  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -112560.172159  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 500}
# -113039.500532  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 700}
# -110533.053647  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -111462.831838  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -111676.386408  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 500}
# -111801.549409  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 700}
# -106639.740697  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -106979.801295  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -107026.372674  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 500}
# -107027.683654  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 700}
# Best params set: {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# Minimum root mean squared error:  101696.45840030388
# ---------------------------------------------------
# Train root mean squared error: 48418.16932744303
# Val root mean squared error: 104389.66368961197
# Weight: 0.085
# =========== Set 1 ===========
# Finding best hyper-parameters for the model...
# -179513.961805  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -173706.425595  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -172513.326320  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 500}
# -172314.039040  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 700}
# -171491.253239  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -170267.980804  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -170793.148873  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 500}
# -171653.961599  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 700}
# -168651.014148  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -169207.496001  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -170455.063400  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 500}
# -171132.399335  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 700}
# -177280.612770  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 150}
# -173994.437391  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 300}
# -174119.437518  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 500}
# -174070.422731  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 700}
# -171411.103106  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 150}
# -171967.351540  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 300}
# -172997.940602  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 500}
# -173680.710328  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 700}
# -171718.863538  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 150}
# -172840.172381  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 300}
# -173807.456738  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 500}
# -174331.001512  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 700}
# -177337.754474  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 150}
# -174850.270698  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 300}
# -174570.574526  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 500}
# -175337.246493  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 700}
# -176722.123179  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 150}
# -177806.847146  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 300}
# -178862.762847  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 500}
# -179750.356741  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 700}
# -176569.563215  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 150}
# -178079.307898  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 300}
# -178978.809011  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 500}
# -179497.545490  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 700}
# -179093.471189  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -177492.421336  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -177272.440680  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 500}
# -177584.385451  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 700}
# -178584.751330  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -179066.015163  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -180628.432079  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 500}
# -181456.612900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 700}
# -180209.865529  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -181492.951989  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -182052.869632  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 500}
# -182301.460274  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 700}
# Best params set: {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# Minimum root mean squared error:  168651.01414847872
# ---------------------------------------------------
# Train root mean squared error: 79421.78123851362
# Val root mean squared error: 176082.5932388474
# Weight: 0.241
# =========== Set 2 ===========
# Finding best hyper-parameters for the model...
# -175417.768481  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -168003.582445  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -165604.315628  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 500}
# -165047.639417  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 700}
# -167116.800040  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -165698.909034  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -166280.738388  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 500}
# -167199.970835  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 700}
# -162448.383967  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -163038.902506  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -164363.909912  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 500}
# -165081.687316  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 700}
# -171903.479172  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 150}
# -168103.309845  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 300}
# -167047.601010  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 500}
# -167845.500183  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 700}
# -166030.473508  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 150}
# -166187.690928  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 300}
# -167685.179183  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 500}
# -168688.087607  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 700}
# -168661.738157  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 150}
# -170157.858360  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 300}
# -171382.297783  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 500}
# -171867.282319  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 700}
# -176046.366381  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 150}
# -172987.252306  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 300}
# -172633.213318  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 500}
# -173437.395504  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 700}
# -170495.210249  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 150}
# -170229.489834  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 300}
# -171717.414387  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 500}
# -172706.064457  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 700}
# -168980.236231  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 150}
#
with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 300}
# -6269288.031342  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 500}
# -6269251.567501  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 700}
# -6561877.029021  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -6563147.187197  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -6563150.164897  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 500}
# -6563130.555073  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 700}
# -6684729.496504  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -6684733.287865  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -6684738.651125  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 500}
# -6684744.014500  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 700}
# -6852829.316467  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -6852818.105889  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -6852803.158841  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 500}
# -6852788.212237  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 700}
# Best params set: {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# Minimum root mean squared error:  5687597.962347756
# ---------------------------------------------------
# Train root mean squared error: 1040179.623037142
# Val root mean squared error: 7623125.994249622
# Weight: 0.003
# =========== Set 12 ===========
# Finding best hyper-parameters for the model...
# -11111233.361264  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -11111234.580293  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -11111232.556965  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 500}
# -11111230.534120  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 700}
# -11327274.148209  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -11327274.148209  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -11327274.148209  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 500}
# -11327274.148209  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 700}
# -11368213.782612  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -11368213.782612  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -11368213.782612  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 500}
# -11368213.782612  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 700}
# -10241389.993466  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 150}
# -10241389.993466  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 300}
# -10241389.993466  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 500}
# -10241389.993466  with:   {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 700}
# -10292243.554486  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 150}
# -10292240.352256  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 300}
# -10292236.082780  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 500}
# -10292231.813488  with:   {'learning_rate': 0.45, 'max_depth': 4, 'n_estimators': 700}
# -10410110.550532  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 150}
# -10410110.550532  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 300}
# -10410110.550532  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 500}
# -10410110.550532  with:   {'learning_rate': 0.45, 'max_depth': 5, 'n_estimators': 700}
# -11190539.147177  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 150}
# -11190539.147177  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 300}
# -11190539.147177  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 500}
# -11190539.147177  with:   {'learning_rate': 0.55, 'max_depth': 3, 'n_estimators': 700}
# -10982871.522090  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 150}
# -10982871.522090  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 300}
# -10982871.522090  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 500}
# -10982871.522090  with:   {'learning_rate': 0.55, 'max_depth': 4, 'n_estimators': 700}
# -10914064.432607  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 150}
# -10914060.555170  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 300}
# -10914055.385411  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 500}
# -10914050.215830  with:   {'learning_rate': 0.55, 'max_depth': 5, 'n_estimators': 700}
# -11382236.739824  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -11382259.954132  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -11382290.906630  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 500}
# -11382321.859230  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 700}
# -11353855.186292  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -11353866.814108  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -11353882.268137  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 500}
# -11353897.724961  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 700}
# -11442986.935289  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -11443008.878098  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -11443038.137892  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 500}
# -11443067.400789  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 700}
# Best params set: {'learning_rate': 0.45, 'max_depth': 3, 'n_estimators': 150}
# Minimum root mean squared error:  10241389.993465984
# ---------------------------------------------------
# Train root mean squared error: 5.93349941863022
# Val root mean squared error: 11248404.500232434
# Weight: 0.001
# ******************************
# Overall train root mean squared error: 130884.5635342448
# Overall val root mean squared error: 378179.9134164545

# %%
# Fine tune model for a specific training subset

save_model = False
training_set = 0      # Choose from 0~12

X_train = area_train_list[training_set].iloc[:, :-1]
X_train['no_of_units'] = X_train['no_of_units'].astype('float32')
Y_train = area_train_list[training_set].iloc[:, -1]

samples_weight = len(area_train_list[training_set]) / len(train_set_copy)
# LightGBM without hyperparameter grid search
task = XGBoost_model()

params = {'learning_rate': 0.3, 
          'n_estimators': 500,
          'max_depth': 4
}


xgb_reg, _, _ = task.build_model(X_train, Y_train, params, grid_search=False)

if save_model:
    save_path = "Models/Area_models/xgboost_area_" + str(training_set) + ".pkl"
    joblib.dump(xgb_reg, save_path)

print("Weight: %.3f" % samples_weight)
# Out:
# Train root mean squared error: 46927.410631333514
# Val root mean squared error: 104919.12018867038
# Weight: 0.085

# %% [markdown]
# ## LightGBM

# %%
class LightGBM_model():
    def __init__(self, **kwargs):
        self.boosting_type = kwargs.get('boosting_type', 'gbdt')
        self.num_leaves = kwargs.get('num_leaves', 16)
        self.learning_rate = kwargs.get('learning_rate', 0.15)
        self.subsample = kwargs.get('subsample', 1.0)
        self.subsample_for_bin = kwargs.get('subsample_for_bin', 200000)
        self.max_depth = kwargs.get('max_depth', 3)
        self.n_estimators = kwargs.get('n_estimators', 150)
        self.min_split_gain = kwargs.get('min_split_gain', 0.0)
        self.min_child_samples = kwargs.get('min_child_samples', 20)
        self.reg_alpha = kwargs.get('reg_alpha', 0)
        self.reg_lambda = kwargs.get('reg_lambda', 1)
        

    def opt_hyper_grid(self, x, y, param_space, num_sets: int=5):

        print('Finding best hyper-parameters for the model...')
        estimator = lgb.LGBMRegressor(boosting_type=self.boosting_type, num_leaves=self.num_leaves, 
                                      max_depth=self.max_depth, learning_rate=self.learning_rate, 
                                      n_estimators=self.n_estimators, subsample_for_bin=self.subsample_for_bin, 
                                      min_split_gain=self.min_split_gain, min_child_samples=self.min_child_samples, 
                                      subsample=self.subsample, reg_alpha=self.reg_alpha, 
                                      reg_lambda=self.reg_lambda, n_jobs=-1)
        lgb_try = GridSearchCV(estimator=estimator, 
                               param_grid=param_space, 
                               cv=KFold(n_splits=num_sets, shuffle=True), 
                               scoring='neg_root_mean_squared_error')
        grid_result = lgb_try.fit(x, y)

        means = grid_result.cv_results_['mean_test_score']
        params = grid_result.cv_results_['params']
        
        for mean, param in zip(means, params):
            print("%f  with:   %r" % (mean, param))

        best_params = lgb_try.best_params_
        print('Best params set:', best_params)
        print('Minimum root mean squared error:', -np.max(means))
        print('---------------------------------------------------')
        self.boosting_type = best_params.get('boosting_type', self.boosting_type)
        self.num_leaves = best_params.get('num_leaves', self.num_leaves)
        self.learning_rate = best_params.get('learning_rate', self.learning_rate)
        self.subsample = best_params.get('subsample', self.subsample)
        self.subsample_for_bin = best_params.get('subsample_for_bin', self.subsample_for_bin)
        self.max_depth = best_params.get('max_depth', self.max_depth)
        self.n_estimators = best_params.get('n_estimators', self.n_estimators)
        self.min_split_gain = best_params.get('min_split_gain', self.min_split_gain)
        self.min_child_samples = best_params.get('min_child_samples', self.min_child_samples)
        self.reg_alpha = best_params.get('reg_alpha', self.reg_alpha)
        self.reg_lambda = best_params.get('reg_lambda', self.reg_lambda)

        return 


    def build_model(self, x, y, params, grid_search: bool = True):
        """
        If use grid search, then each parameter can have multiple values
        
        Example: params = {'learning_rate': [0.1, 0.3],
                           'n_estimators': [100, 200, 300]
                           }
                           
        If do not use grid search, then each parameter should have only one value
        
        Example: params = {'learning_rate': 0.1,
                           'n_estimators': 100
                          }
        
        """
        
        
        if grid_search:
            self.opt_hyper_grid(x, y, params)
        else:

            self.boosting_type = params.get('boosting_type', self.boosting_type)
            self.num_leaves = params.get('num_leaves', self.num_leaves)
            self.learning_rate = params.get('learning_rate', self.learning_rate)
            self.subsample = params.get('subsample', self.subsample)
            self.subsample_for_bin = params.get('subsample_for_bin', self.subsample_for_bin)
            self.max_depth = params.get('max_depth', self.max_depth)
            self.n_estimators = params.get('n_estimators', self.n_estimators)
            self.min_split_gain = params.get('min_split_gain', self.min_split_gain)
            self.min_child_samples = params.get('min_child_samples', self.min_child_samples)
            self.reg_alpha = params.get('reg_alpha', self.reg_alpha)
            self.reg_lambda = params.get('reg_lambda', self.reg_lambda)

        lgb_reg = lgb.LGBMRegressor(boosting_type=self.boosting_type, num_leaves=self.num_leaves, 
                                      max_depth=self.max_depth, learning_rate=self.learning_rate, 
                                      n_estimators=self.n_estimators, subsample_for_bin=self.subsample_for_bin, 
                                      min_split_gain=self.min_split_gain, min_child_samples=self.min_child_samples, 
                                      subsample=self.subsample, reg_alpha=self.reg_alpha, 
                                      reg_lambda=self.reg_lambda, n_jobs=- 1)
        # 10-folder cross-validation
        sk = KFold(n_splits=5, shuffle=True)
        scores_train = list()
        scores_val = list()
        for train_ind, val_ind in sk.split(x, y):
            train_x = x.iloc[train_ind].values
            train_y = y.iloc[train_ind]
            val_x = x.iloc[val_ind].values
            val_y = y.iloc[val_ind]

            lgb_reg.fit(train_x, train_y)
            pred_train_lgb = lgb_reg.predict(train_x)
            pred_val_lgb = lgb_reg.predict(val_x)

            score_train = mean_squared_error(train_y, pred_train_lgb, squared=False)
            scores_train.append(score_train)
            score_val = mean_squared_error(val_y, pred_val_lgb, squared=False)
            scores_val.append(score_val)

        print('Train root mean squared error:', np.mean(scores_train))
        print('Val root mean squared error:', np.mean(scores_val))

        return lgb_reg, np.mean(scores_train), np.mean(scores_val)

# %%
# Grid search hyperparameters for each model

train_error = 0
val_error = 0
save_model = True

for i in range(len(area_train_list)):
    print("=========== Set %d ===========" % i)
    samples_weight = len(area_train_list[i]) / len(train_set_copy)
    X_train = area_train_list[i].iloc[:, :-1]
    Y_train = area_train_list[i].iloc[:, -1]
    
    task = LightGBM_model()

    params = {
        'learning_rate': [0.3, 0.5, 0.7],
        'n_estimators': [200, 300, 500],
        'max_depth':[3, 4],
        'min_child_samples': [50, 100, 200],
        'num_leaves': [16, 32]
    }

    lgb_reg, scores_train, scores_val = task.build_model(X_train, Y_train, params, grid_search=True)
    if save_model:
        save_path = "Models/Area_models/lightgbm_area_" + str(i) + ".pkl"
        joblib.dump(lgb_reg, save_path)

    print("Weight: %.3f" % samples_weight)
    train_error += scores_train * samples_weight
    val_error += scores_val * samples_weight

print("*" * 30)
print("Overall train root mean squared error: %.10f" % train_error)
print("Overall val root mean squared error: %.10f" % val_error)
# Out:
# =========== Set 0 ===========
# Finding best hyper-parameters for the model...
# -106077.595502  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -106077.595502  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -106293.387442  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -106293.387442  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -107430.315051  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -107430.315051  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
#
with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -226414.042979  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -226414.042979  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -222133.593111  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -222133.593111  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -219388.201752  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -219388.201752  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -232328.475035  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -232328.475035  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -225045.851532  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -225045.851532  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -218517.929325  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -218517.929325  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# -230934.134696  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -230934.134696  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -227474.166517  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -227474.166517  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -225222.232361  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# ...
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -17493031.599900  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# Minimum root mean squared error: 17493031.599899843
# ---------------------------------------------------
# Train root mean squared error: 17346713.438570984
# Val root mean squared error: 17429343.84891792
# Weight: 0.003
# =========== Set 12 ===========
# Finding best hyper-parameters for the model...
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 100, 'n_estimators': 500, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 200, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 300, 'num_leaves': 32}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 16}
# -20174891.828910  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 200, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# Minimum root mean squared error: 20174891.8289101
# ---------------------------------------------------
# Train root mean squared error: 19239405.641747884
# Val root mean squared error: 19877314.662311994
# Weight: 0.001
# ******************************
# Overall train root mean squared error: 255171.8057962901
# Overall val root mean squared error: 425785.5748455320

# %%
# Fine tune model for a specific training subset

save_model = False
training_set = 0      # Choose from 0~12
X_train = area_train_list[training_set].iloc[:, :-1]
Y_train = area_train_list[training_set].iloc[:, -1]
samples_weight = len(area_train_list[training_set]) / len(train_set_copy)

task = LightGBM_model()

params = {'learning_rate': 0.5, 
          'min_child_samples': 20,
          'min_split_gain': 0, 
          'n_estimators': 300}


lgb_reg, _, _ = task.build_model(X_train, Y_train, params, grid_search=False)

if save_model:
    save_path = "Models/Area_models/lightgbm_area_" + str(training_set) + ".pkl"
    joblib.dump(lgb_reg, save_path)

print("Weight: %.3f" % samples_weight)
# Out:
# Train root mean squared error: 60852.04476759261
# Val root mean squared error: 106228.79342660175
# Weight: 0.085

# %% [markdown]
# ## Test with Kaggle test set

# %%
# Import test dataset
data_type = {
            'listing_id': int,
            'name': str,
             'street': str,
             'type': str,
             'model': str,
             'market_segment': str,
             'type_of_area': str,
             'bedrooms': str,
             'bathrooms': float,
             'district': int,
             'region': str,
             'planning_area': str,
             'subszone': str,
             'lat': float,
             'lng': float,
             'tenure': str,
             'built_year': float,
             'no_of_units': float,
             'area_size': float,
             'eco_category': str,
             'accessibility': str,
             'date_listed': str
             }

test_set = pd.read_csv("Data/test.csv", dtype=data_type)


# Make a copy
test_set_copy = test_set.copy()

test_set_copy.head(3)

# Check nan for each column
for col_name, _ in test_set_copy.iteritems():
    if len(test_set_copy[test_set_copy[col_name].isna()])>0:
        print("%s: %s rows" % (col_name, len(test_set_copy[test_set_copy[col_name].isna()])))
# Out:
# model: 388 rows
# bedrooms: 118 rows
# bathrooms: 337 rows
# tenure: 85 rows
# built_year: 2875 rows
# no_of_units: 326 rows

# %%
def convert_test_set(X_test):
    # Data preprocessing for test data set
    
    #transformaing bedrooms, i.e: from 2+1 to 3
    X_test['bedrooms']=X_test['bedrooms'].apply(lambda x: x if type(x)==float else eval(x))
    
    # Deal with NaN data
    X_test['bedrooms'].fillna(value=bedroom_median, inplace=True)
    X_test['bathrooms'].fillna(value=bathroom_median, inplace=True)
    X_test['built_year'].fillna(value=built_year_median, inplace=True)
    X_test['no_of_units'].fillna(value=no_of_units_median, inplace=True)

    # Check column 'tenure', treat houses that are not 'freehold' as 'leasehold', also fill NaN with 'leasehold'
    X_test['tenure'].where(X_test['tenure']=='freehold', other='leasehold', inplace=True)

    # Drop rows whose area_size is NaN
    X_test.dropna(axis=0, subset=['area_size'], inplace=True)
    
    # Convert some string columns to 0-1 verctors
    # Type
    type_mapping = {'apartment': 0 ,'condominium' : 1}
    X_test['type'] = X_test['type'].map(type_mapping)
    # Tenure
    tenure_mapping = {'freehold':0 ,'leasehold' : 1}
    X_test['tenure'] = X_test['tenure'].map(tenure_mapping)
    
    # For 'build_year', use 2022 - original year to get current age of houses
    X_test['built_year'] = 2022 - X_test['built_year']

    # For no_of_units, divide all houses into 10 categories, manually set lowest limit=0 and highest limit=10000
    X_test['no_of_units'] = pd.cut(X_test['no_of_units'], bins=cut_bins, labels=cut_labels, include_lowest=True).values
    
    # Convert name, street, region and planning area to numerical values
    X_test['name'] = X_test['name'].map(name_mapping)
    X_test['street'] = X_test['street'].map(street_mapping)
    X_test['region'] = X_test['region'].map(region_mapping)
    X_test['planning_area'] = X_test['planning_area'].map(planning_area_mapping)


    return

# %%
convert_test_set(test_set_copy)
test_set_copy.reset_index(drop=True, inplace=True)
test_set_copy.head(3)
# Out:
#    listing_id    name  street  type        model market_segment type_of_area  \
# 0     1487111   824.0  1124.0     1  condominium            ocr       strata
# 1     6794066  1494.0  2563.0     1  condominium            ocr       strata
# 2     4027017   130.0   903.0     0    apartment            ocr       strata
#
#    bedrooms  bathrooms  district  ...      subszone       lat         lng  \
# 0       2.0        2.0        10  ...  farrer court  1.313566  103.803218
# 1       3.0        2.0        15  ...   tanjong rhu  1.298437  103.884408
# 2       3.0        1.0        15  ...       frankel  1.317851  103.908905
#
#    tenure  built_year  no_of_units  area_size   eco_category  accessibility  \
# 0       0         8.0        630.0      710.0  uncategorized        guarded
# 1       0         6.0        138.5     1055.0  uncategorized        guarded
# 2       0         9.0        138.5      463.0  uncategorized        guarded
#
#   date_listed
# 0  2021-12-12
# 1  2021-10-12
# 2  2021-12-23
#
# [3 rows x 22 columns]

# %%
test_distance = cal_distance(test_set_copy, is_train=False)
test_distance.reset_index(drop=True, inplace=True)

# %%
# Option 1: Test set without "distance" information
# X_test_without_auxiliary_data = test_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'lat', 'lng', 'tenure', 'built_year', 'no_of_units', 'area_size']]
X_test_without_auxiliary_data = test_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'tenure', 'built_year', 'no_of_units', 'area_size']]
X_test_without_auxiliary_data.head(3)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       2.0        2.0        10       0         8.0       630.0
# 1     1       3.0        2.0        15       0         6.0       138.5
# 2     0       3.0        1.0        15       0         9.0       138.5
#
#    area_size
# 0      710.0
# 1     1055.0
# 2      463.0

# %%
# Option 2: Test set with "distance" information
X_test_plus_auxiliary_data = pd.concat([X_test_without_auxiliary_data, test_distance], axis=1)
# X_test_plus_auxiliary_data = pd.concat([X_test_without_auxiliary_data, test_distance[['to_primary_schools', 'to_secondary_schools']]], axis=1)
X_test_plus_auxiliary_data.head(3)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       2.0        2.0        10       0         8.0       630.0
# 1     1       3.0        2.0        15       0         6.0       138.5
# 2     0       3.0        1.0        15       0         9.0       138.5
#
#    area_size  to_commercial_centres  to_hawker_centres  to_primary_schools  \
# 0      710.0               1.659712           0.410398            0.980559
# 1     1055.0               2.415213           0.446516            1.469982
# 2      463.0               1.712861           0.587265            0.893951
#
#    to_secondary_schools  to_shopping_malls  to_train_stations
# 0              1.048619           1.128913           0.654270
# 1              0.249159           0.969806           0.888254
# 2              1.343460           1.475109           0.572349

# %%
# Predict
model_dict = {
    0: "gbdt",
    1: "xgboost",
    2: "lightgbm"

}

area_model_index = 0
model_root_path = "Models/Area_models/" + model_dict[area_model_index]

area_model_0 = joblib.load(model_root_path + "_area_0.pkl")
area_model_1 = joblib.load(model_root_path + "_area_1.pkl")
area_model_2 = joblib.load(model_root_path + "_area_2.pkl")
area_model_3 = joblib.load(model_root_path + "_area_3.pkl")
area_model_4 = joblib.load(model_root_path + "_area_4.pkl")
area_model_5 = joblib.load(model_root_path + "_area_5.pkl")
area_model_6 = joblib.load(model_root_path + "_area_6.pkl")
area_model_7 = joblib.load(model_root_path + "_area_7.pkl")
area_model_8 = joblib.load(model_root_path + "_area_8.pkl")
area_model_9 = joblib.load(model_root_path + "_area_9.pkl")
area_model_10 = joblib.load(model_root_path + "_area_10.pkl")
area_model_11 = joblib.load(model_root_path + "_area_11.pkl")
area_model_12 = joblib.load(model_root_path + "_area_12.pkl")


kaggle_Y_pred = np.zeros(shape=(len(X_test_plus_auxiliary_data),))
# area_split_points = [0, 500, 750, 1000, 1200, 1500, 2000, 2500, 3000, 4000, 5000, 7500, 10000]
area_models = [area_model_0, area_model_1, area_model_2, area_model_3, area_model_4,
               area_model_5, area_model_6, area_model_7, area_model_8, area_model_9,
               area_model_10, area_model_11, area_model_12]

for i in range(len(X_test_plus_auxiliary_data)):
    sample_input = X_test_plus_auxiliary_data.iloc[i,:]
    sample_area = sample_input['area_size']
    sample_input = sample_input.values.reshape(1, -1)
    
    isFound = False
    for j in range(len(area_models)-2):
        if area_split_points[j] <= sample_area < area_split_points[j+1]:
            kaggle_Y_pred[i] = area_models[j].predict(sample_input)
            isFound = True
            break
    if not isFound:
        kaggle_Y_pred[i] = area_models[-1].predict(sample_input)

# %%
kaggle_Y_pred
# Out:
# array([1986949.39551093, 2563707.37107458,  884107.33744582, ...,
#        1619155.27405892,  936396.85780296, 7549260.23794854])

# %%
pred_df = pd.Series(kaggle_Y_pred, name='Predicted')
pred_df

# Save the results
sava_root_path = "Results/Area_model_results/" + model_dict[model_index] + "_"
pred_df.to_csv(sava_root_path + "gs_with_aux.csv", header=['Predicted'], index_label=['Id'])
