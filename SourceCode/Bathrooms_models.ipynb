# %%
# Import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import training dataset

data_type = {
            'listing_id': int,
            'name': str,
             'street': str,
             'type': str,
             'model': str,
             'market_segment': str,
             'type_of_area': str,
             'bedrooms': str,
             'bathrooms': float,
             'district': int,
             'region': str,
             'planning_area': str,
             'subszone': str,
             'lat': float,
             'lng': float,
             'tenure': str,
             'built_year': float,
             'no_of_units': float,
             'area_size': float,
             'eco_category': str,
             'accessibility': str,
             'date_listed': str,
             'price': int}

train_set = pd.read_csv("Data/train.csv", dtype=data_type)


# Make a copy
train_set_copy = train_set.copy()

# %% [markdown]
# # New Section

# %%
# Take a glance on dataset
train_set_copy.head(5)
# Out:
#    listing_id                  name             street         type  \
# 0     6998418              seascape       57 cove way   condominium
# 1     2046604             la maison  10 moulmein rise     apartment
# 2     7563513                  viva    2 suffolk walk   condominium
# 3     3071445       urban treasures   205 jalan eunos   condominium
# 4     9667539  infini at east coast    east coast road    apartment
#
#          model market_segment type_of_area bedrooms  bathrooms  district  ...  \
# 0  condominium            ocr       strata        3        4.0         4  ...
# 1    apartment            ocr       strata        3        3.0        11  ...
# 2  condominium            ocr       strata        4        3.0        11  ...
# 3  condominium            ocr       strata        3        2.0        14  ...
# 4    apartment            ocr       strata        3        3.0        15  ...
#
#         lat         lng              tenure  built_year  no_of_units  \
# 0  1.239337  103.837487  leasehold/99 years      2011.0        151.0
# 1  1.319533  103.847030            freehold      1999.0         24.0
# 2  1.315656  103.844445            freehold      2012.0        235.0
# 3  1.329367  103.905791            freehold         NaN        237.0
# 4  1.309176  103.911352            freehold         NaN         36.0
#
#   area_size   eco_category  accessibility  date_listed    price
# 0    2336.0  uncategorized        guarded   2021-05-04  5390000
# 1    1259.0  uncategorized        guarded   2021-05-07  2310000
# 2    1959.0  uncategorized        guarded   2021-06-30  5279500
# 3     883.0  uncategorized        guarded   2022-01-02  1843600
# 4    1066.0  uncategorized        guarded   2021-12-24  2262700
#
# [5 rows x 23 columns]

# %%
# Check nan for each column
for col_name, _ in train_set_copy.iteritems():
    if len(train_set_copy[train_set_copy[col_name].isna()])>0:
        print("%s: %s rows" % (col_name, len(train_set_copy[train_set_copy[col_name].isna()])))
# Out:
# model: 1280 rows
# bedrooms: 404 rows
# bathrooms: 1236 rows
# tenure: 287 rows
# built_year: 10043 rows
# no_of_units: 1042 rows
# area_size: 2 rows

# %%
# Deal with NaN data

#transformaing bedrooms, i.e: from 2+1 to 3
train_set_copy['bedrooms']=train_set_copy['bedrooms'].apply(lambda x: x if type(x)==float else eval(x))

# Get median for three columns: bathrooms, built_year, no_of_units
bedroom_median = np.median(train_set_copy['bedrooms'].dropna())
bathroom_median = np.median(train_set_copy['bathrooms'].dropna())
built_year_median = np.median(train_set_copy['built_year'].dropna())
no_of_units_median = np.median(train_set_copy['no_of_units'].dropna())

print("bedroom_median: ", bedroom_median)
print("bathroom_median: ", bathroom_median)
print("built_year_median: ", built_year_median)
print("no_of_units_median: ", no_of_units_median)

train_set_copy['bedrooms'].fillna(value=bedroom_median, inplace=True)
train_set_copy['bathrooms'].fillna(value=bathroom_median, inplace=True)
train_set_copy['built_year'].fillna(value=built_year_median, inplace=True)
train_set_copy['no_of_units'].fillna(value=no_of_units_median, inplace=True)

# Check column 'tenure', treat houses that are not 'freehold' as 'leasehold', also fill NaN with 'leasehold'
train_set_copy['tenure'].where(train_set_copy['tenure']=='freehold', other='leasehold', inplace=True)

# Drop rows whose area_size is NaN
train_set_copy.dropna(axis=0, subset=['area_size'], inplace=True)
# Out:
# bedroom_median:  3.0
# bathroom_median:  2.0
# built_year_median:  2014.0
# no_of_units_median:  366.0

# %%
# Convert some string columns to 0-1 verctors

# Type
type_mapping = {'apartment': 0 ,'condominium' : 1}
train_set_copy['type'] = train_set_copy['type'].map(type_mapping)

# Tenure
tenure_mapping = {'freehold':0 ,'leasehold' : 1}
train_set_copy['tenure'] = train_set_copy['tenure'].map(tenure_mapping)


# For 'build_year', use 2022 - original year to get current age of houses
train_set_copy['built_year'] = 2022 - train_set_copy['built_year']

# For no_of_units, divide all houses into 10 categories, manually set lowest limit=0 and highest limit=10000
cut_bins = np.zeros(shape=(11,))
cut_bins = np.quantile(train_set_copy['no_of_units'], [0.1*i for i in range(11)])
cut_labels = [(cut_bins[i] + cut_bins[i+1])/2 for i in range(10)]
cut_bins[0], cut_bins[-1] = 0, 10000000
train_set_copy['no_of_units'] = pd.cut(train_set_copy['no_of_units'], bins=cut_bins, labels=cut_labels, include_lowest=True).values

# Transfer name, street, region and planning area to numerical values
name_mapping = {label:idx for idx,label in enumerate(set(train_set_copy['name']))}
street_mapping = {label:idx for idx,label in enumerate(set(train_set_copy['street']))}
region_mapping = {'north-east region': 0,
                 'north region': 1,
                 'west region': 2,
                 'east region': 3,
                 'central region': 4}
planning_area_mapping = {label:idx for idx,label in enumerate(set(train_set_copy['planning_area']))}

train_set_copy['name'] = train_set_copy['name'].map(name_mapping)
train_set_copy['street'] = train_set_copy['street'].map(street_mapping)
train_set_copy['region'] = train_set_copy['region'].map(region_mapping)
train_set_copy['planning_area'] = train_set_copy['planning_area'].map(planning_area_mapping)

# %%
train_set_copy.reset_index(drop=True, inplace=True)
train_set_copy.head(3)
# Out:
#    listing_id  name  street  type        model market_segment type_of_area  \
# 0     6998418   240    1095     1  condominium            ocr       strata
# 1     2046604   209    2802     0    apartment            ocr       strata
# 2     7563513  1060    2836     1  condominium            ocr       strata
#
#    bedrooms  bathrooms  district  ...       lat         lng tenure  \
# 0       3.0        4.0         4  ...  1.239337  103.837487      1
# 1       3.0        3.0        11  ...  1.319533  103.847030      0
# 2       4.0        3.0        11  ...  1.315656  103.844445      0
#
#    built_year  no_of_units  area_size   eco_category accessibility  \
# 0        11.0        138.5     2336.0  uncategorized       guarded
# 1        23.0         28.5     1259.0  uncategorized       guarded
# 2        10.0        217.0     1959.0  uncategorized       guarded
#
#    date_listed    price
# 0   2021-05-04  5390000
# 1   2021-05-07  2310000
# 2   2021-06-30  5279500
#
# [3 rows x 23 columns]

# %%
# Check correlation between 'price' and other columns
print(train_set_copy.corr(method='pearson')['price'])
# Out:
# listing_id      -0.000812
# name            -0.034268
# street           0.022538
# type             0.017215
# bedrooms         0.430928
# bathrooms        0.523360
# district        -0.219530
# region           0.196188
# planning_area    0.043602
# lat             -0.233974
# lng             -0.066018
# tenure          -0.126546
# built_year       0.008851
# area_size        0.869712
# price            1.000000
# Name: price, dtype: float64

# %%
# Import auxiliary data
commercial_centres = pd.read_csv("Data/auxiliary-data/sg-commerical-centres.csv")
hawker_centres = pd.read_csv("Data/auxiliary-data/sg-gov-markets-hawker-centres.csv")
primary_schools = pd.read_csv("Data/auxiliary-data/sg-primary-schools.csv")
secondary_schools = pd.read_csv("Data/auxiliary-data/sg-secondary-schools.csv")
shopping_malls = pd.read_csv("Data/auxiliary-data/sg-shopping-malls.csv")
stations = pd.read_csv("Data/auxiliary-data/sg-train-stations.csv")

# %%
# Calculate distance in km with lat & lng
def haversine_batch(train_lng, train_lat, place_lng, place_lat):  # lng1，lat1，lng2，lat2
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    """

    place_lat = np.radians(place_lat)
    place_lng = np.radians(place_lng)

    train_lat = np.radians(train_lat)
    train_lng = np.radians(train_lng)

    dlat = place_lat - train_lat
    dlng = place_lng - train_lng

    a = np.sin(dlat / 2) ** 2 + np.cos(train_lat) * np.cos(place_lat) * np.sin(dlng / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371 # Radius of the earth in km
    return c * r


def cal_distance(X, is_train: bool):
    # Find distance to nearest facilities for each house
    facilities = [commercial_centres, hawker_centres, primary_schools, secondary_schools, shopping_malls, stations]

    res = []

    for f in facilities:

        distance = np.full((len(X), 1), np.inf)

        for _, row in f.iterrows():
            d = haversine_batch(X['lng'].values, X['lat'].values, row['lng'], row['lat']).reshape(-1, 1)
            distance = np.minimum(distance, d)
        
        res.append(distance)
        
    if is_train:
        res.append(X['price'].values.reshape(-1, 1))
        pd_distance = pd.DataFrame(data=np.squeeze(np.asarray(res)).swapaxes(0, 1),
                              columns=['to_commercial_centres', 'to_hawker_centres', 'to_primary_schools',
                                       'to_secondary_schools', 'to_shopping_malls', 'to_train_stations', 'price'])
    else:
        pd_distance = pd.DataFrame(data=np.squeeze(np.asarray(res)).swapaxes(0, 1),
                          columns=['to_commercial_centres', 'to_hawker_centres', 'to_primary_schools',
                                   'to_secondary_schools', 'to_shopping_malls', 'to_train_stations'])
    return pd_distance

# %%
# Find distance
train_distance = cal_distance(train_set_copy, is_train=True)
# Discover correlations between price to each other parameter
print(train_distance.corr(method='pearson')['price'])
# Out:
# to_commercial_centres    0.020541
# to_hawker_centres        0.006066
# to_primary_schools       0.189241
# to_secondary_schools     0.196791
# to_shopping_malls       -0.061559
# to_train_stations        0.020612
# price                    1.000000
# Name: price, dtype: float64

# %%
# Show pd_distance
train_distance.reset_index(drop=True, inplace=True)
train_distance.head(3)
# Out:
#    to_commercial_centres  to_hawker_centres  to_primary_schools  \
# 0               5.604095           4.079855            4.064895
# 1               0.407610           0.519457            0.235428
# 2               0.498692           0.648320            0.294793
#
#    to_secondary_schools  to_shopping_malls  to_train_stations      price
# 0              4.429845           3.218556           3.409821  5390000.0
# 1              1.263926           0.339015           0.370228  2310000.0
# 2              1.075413           0.201332           0.536424  5279500.0

# %%
# Option 1: train dataset without "distance" information
# X_train_without_auxiliary_data = train_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'lat', 'lng', 'tenure', 'built_year', 'no_of_units', 'area_size']]
train_without_auxiliary_data = train_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'tenure', 'built_year', 'no_of_units', 'area_size', 'price']]
train_without_auxiliary_data.head(3)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       3.0        4.0         4       1        11.0       138.5
# 1     0       3.0        3.0        11       0        23.0        28.5
# 2     1       4.0        3.0        11       0        10.0       217.0
#
#    area_size    price
# 0     2336.0  5390000
# 1     1259.0  2310000
# 2     1959.0  5279500

# %%
# Option 2: train dataset with "distance" information
train_plus_auxiliary_data = pd.concat([train_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'tenure', 'built_year', 'no_of_units', 'area_size']], train_distance.iloc[:, :-1], train_set_copy['price']], axis=1)
train_plus_auxiliary_data.head(3)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       3.0        4.0         4       1        11.0       138.5
# 1     0       3.0        3.0        11       0        23.0        28.5
# 2     1       4.0        3.0        11       0        10.0       217.0
#
#    area_size  to_commercial_centres  to_hawker_centres  to_primary_schools  \
# 0     2336.0               5.604095           4.079855            4.064895
# 1     1259.0               0.407610           0.519457            0.235428
# 2     1959.0               0.498692           0.648320            0.294793
#
#    to_secondary_schools  to_shopping_malls  to_train_stations    price
# 0              4.429845           3.218556           3.409821  5390000
# 1              1.263926           0.339015           0.370228  2310000
# 2              1.075413           0.201332           0.536424  5279500

# %%
all_data = train_plus_auxiliary_data
bathrooms_split_points = [1, 2, 3, 4, 5]
print("Data distribution:")
# bathrooms
# 1
bathrooms_set_0 = all_data[(all_data['bathrooms'] >= bathrooms_split_points[0])&(all_data['bathrooms'] < bathrooms_split_points[1])]
print("1: ", len(bathrooms_set_0))
# 2
bathrooms_set_1 = all_data[(all_data['bathrooms'] >= bathrooms_split_points[1])&(all_data['bathrooms'] < bathrooms_split_points[2])]
print("2: ", len(bathrooms_set_1))
# 3
bathrooms_set_2 = all_data[(all_data['bathrooms'] >= bathrooms_split_points[2])&(all_data['bathrooms'] < bathrooms_split_points[3])]
print("3: ", len(bathrooms_set_2))
# 4
bathrooms_set_3 = all_data[(all_data['bathrooms'] >= bathrooms_split_points[3])&(all_data['bathrooms'] < bathrooms_split_points[4])]
print("4: ", len(bathrooms_set_3))
# 5~10
bathrooms_set_4 = all_data[all_data['bathrooms'] >= bathrooms_split_points[-1]]
print("5~10: ", len(bathrooms_set_4))
# Out:
# Data distribution:
# 1:  6631
# 2:  10977
# 3:  4950
# 4:  2292
# 5~10:  1196

# %% [markdown]
# # Model Training

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.preprocessing import StandardScaler
import joblib
import xgboost as xgb
import lightgbm as lgb

# %matplotlib inline

# %%
bathrooms_train_list = [bathrooms_set_0, bathrooms_set_1, bathrooms_set_2, bathrooms_set_3, bathrooms_set_4]

# %% [markdown]
# ## GBDT

# %%
class GBDT_model():
    def __init__(self, **kwargs):
        self.loss = kwargs.get('loss', 'ls')
        self.learning_rate = kwargs.get('learning_rate', 0.15)
        self.subsample = kwargs.get('subsample', 1.0)
        self.max_depth = kwargs.get('max_depth', 2)
        self.n_estimators = kwargs.get('n_estimators', 150)
        self.max_leaf_nodes = kwargs.get('max_leaf_nodes', None)
        self.min_samples_leaf = kwargs.get('min_samples_leaf', 3)
        self.min_samples_split = kwargs.get('min_samples_split', 5)
        self.alpha = kwargs.get('alpha', 0.9)

    def opt_hyper_grid(self, x, y, param_space, num_sets: int=5):

        print('Finding best hyper-parameters for the model...')
        estimator = GradientBoostingRegressor(loss=self.loss, learning_rate=self.learning_rate,
                                              subsample=self.subsample, max_depth=self.max_depth,
                                              n_estimators=self.n_estimators,
                                              max_leaf_nodes=self.max_leaf_nodes,
                                              min_samples_leaf=self.min_samples_leaf,
                                              min_samples_split=self.min_samples_split,
                                              alpha=self.alpha)
        gbdt = GridSearchCV(estimator=estimator, 
                            param_grid=param_space, 
                            cv=KFold(n_splits=num_sets, shuffle=True), 
                            scoring='neg_root_mean_squared_error')
        grid_result = gbdt.fit(x, y)

        means = grid_result.cv_results_['mean_test_score']
        params = grid_result.cv_results_['params']

        for mean, param in zip(means, params):
            print("%f  with:   %r" % (mean, param))

        best_params = gbdt.best_params_
        print('Best params set:', best_params)
        print('Minimum root mean squared error:', -np.max(means))
        print('---------------------------------------------------')
        
        self.learning_rate = best_params.get('learning_rate', self.learning_rate)
        self.max_depth = best_params.get('max_depth', self.max_depth)
        self.subsample = best_params.get('subsample', self.subsample)
        self.n_estimators = best_params.get('n_estimators', self.n_estimators)
        self.max_leaf_nodes = best_params.get('max_leaf_nodes', self.max_leaf_nodes)
        self.min_samples_leaf = best_params.get('min_samples_leaf', self.min_samples_leaf)
        self.min_samples_split = best_params.get('min_samples_split', self.min_samples_split)
        self.alpha = best_params.get('alpha', self.alpha)

        return 


    def build_model(self, x, y, params, grid_search: bool = True):
        """
        If use grid search, then each parameter can have multiple values
        
        Example: params = {'learning_rate': [0.1, 0.3],
                           'n_estimators': [100, 200, 300]
                           }
                           
        If do not use grid search, then each parameter should have only one value
        
        Example: params = {'learning_rate': 0.1,
                           'n_estimators': 100
                          }
        
        """
        
        
        if grid_search:
            self.opt_hyper_grid(x, y, params)
        else:

            self.learning_rate = params.get('learning_rate', self.learning_rate)
            self.max_depth = params.get('max_depth', self.max_depth)
            self.subsample = params.get('subsample', self.subsample)
            self.n_estimators = params.get('n_estimators', self.n_estimators)
            self.max_leaf_nodes = params.get('max_leaf_nodes', self.max_leaf_nodes)
            self.min_samples_leaf = params.get('min_samples_leaf', self.min_samples_leaf)
            self.min_samples_split = params.get('min_samples_split', self.min_samples_split)
            self.alpha = params.get('alpha', self.alpha)

        gbdt = GradientBoostingRegressor(loss=self.loss, learning_rate=self.learning_rate,
                                         subsample=self.subsample, max_depth=self.max_depth,
                                         n_estimators=self.n_estimators,
                                         max_leaf_nodes=self.max_leaf_nodes,
                                         min_samples_leaf=self.min_samples_leaf,
                                         min_samples_split=self.min_samples_split, alpha=self.alpha)
        # 10-folder cross validation
        sk = KFold(n_splits=10, shuffle=True)
        scores_train = list()
        scores_val = list()
        for train_ind, val_ind in sk.split(x, y):
            train_x = x.iloc[train_ind].values
            train_y = y.iloc[train_ind]
            val_x = x.iloc[val_ind].values
            val_y = y.iloc[val_ind]

            gbdt.fit(train_x, train_y)
            pred_train_gbdt = gbdt.predict(train_x)
            pred_val_gbdt = gbdt.predict(val_x)

            score_train = mean_squared_error(train_y, pred_train_gbdt, squared=False)
            scores_train.append(score_train)
            score_val = mean_squared_error(val_y, pred_val_gbdt, squared=False)
            scores_val.append(score_val)

        print('Train root mean squared error:', np.mean(scores_train))
        print('Val root mean squared error:', np.mean(scores_val))

        return gbdt, np.mean(scores_train), np.mean(scores_val)

# %%
# Grid search hyperparameters for each model

train_error = 0
val_error = 0
save_model = True

for i in range(len(bathrooms_train_list)):
    print("=========== Set %d ===========" % i)
    samples_weight = len(bathrooms_train_list[i]) / len(train_set_copy)
    X_train = bathrooms_train_list[i].iloc[:, :-1]
    Y_train = bathrooms_train_list[i].iloc[:, -1]
    
    task = GBDT_model()

    params = {
        'learning_rate': [0.3, 0.4, 0.5],
        'max_depth': [2, 4],
        'min_samples_leaf': [10, 50, 80],
        'n_estimators': [150, 300, 500]

    }

    gbdt_reg, scores_train, scores_val = task.build_model(X_train, Y_train, params, grid_search=True)
    if save_model:
        save_path = "Models/Bathrooms_models/gbdt_bathrooms_" + str(i) + ".pkl"
        joblib.dump(gbdt_reg, save_path)

    print("Weight: %.3f" % samples_weight)
    train_error += scores_train * samples_weight
    val_error += scores_val * samples_weight

print("*" * 30)
print("Overall train root mean squared error: %.10f" % train_error)
print("Overall val root mean squared error: %.10f" % val_error)
# Out:
# =========== Set 0 ===========
# Finding best hyper-parameters for the model...
# -237429.522223  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -219204.265062  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -210252.237869  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -285866.039876  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -266800.188678  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -253146.050100  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -293423.741984  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -272662.922492  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -255318.367062  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -199762.974795  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -187545.363243  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -185336.440082  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -266129.386006  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -252771.491390  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -243314.507025  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -275357.935719  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -257922.429121  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -243170.139999  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -230160.501003  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -213132.922928  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -206107.204849  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -272949.800325  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -253379.082137  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -241580.621685  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -288076.554763  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -262601.357730  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -244041.590184  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -188178.544587  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -183486.755191  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -182551.222101  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -254944.968608  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -238247.499694  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -234542.332846  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -268318.405448  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -249172.282156  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -237898.932921  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -214286.043895  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -204263.460021  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -198816.067484  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -265774.136170  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -246266.396197  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -235987.077847  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -278707.201425  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -254292.516789  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -239830.446567  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -199505.594258  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -195554.833194  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -194631.094870  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -250296.678677  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -238900.210344  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -236115.506597  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -263259.720258  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -242624.512704  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -235203.755990  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# Minimum root mean squared error: 182551.22210050948
# ---------------------------------------------------
# Train root mean squared error: 73135.19345513424
# Val root mean squared error: 210082.6753176138
# Weight: 0.255
# =========== Set 1 ===========
# Finding best hyper-parameters for the model...
# -810961.966143  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -784958.242428  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -775439.106657  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1270420.085767  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1186754.740630  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1137990.331107  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1525899.014546  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1396396.087703  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1322908.390894  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -723129.135435  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -706261.080691  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -708504.294401  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1119248.443580  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1075922.973840  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1054460.559863  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1256986.497484  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1134862.215412  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1100048.297277  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -795225.496942  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -777278.274066  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -761599.425910  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1269692.285452  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1177495.158586  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1136926.545851  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1453274.216646  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1336708.455102  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1278322.516793  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -729454.356935  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -717088.509215  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -712342.402581  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1119756.701610  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1075112.821567  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1057814.732907  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1211723.148859  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1129911.979623  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1117718.775832  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -785002.371034  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -755361.433736  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -746161.834990  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1226600.914663  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1153461.581824  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1138453.392880  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1417958.696356  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1319500.332640  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1268004.397819  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -737480.198920  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -729836.916693  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -728913.015583  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1108981.966072  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1079733.421818  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1076827.416430  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1159074.759015  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1110993.778689  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1099772.819982  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# Minimum root mean squared error: 706261.0806906332
# ---------------------------------------------------
# Train root mean squared error: 204382.02248467776
# Val root mean squared error: 566482.5121810341
# Weight: 0.421
# =========== Set 2 ===========
# Finding best hyper-parameters for the model...
# -920574.552509  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -895240.947941  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -884844.100801  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -951019.917094  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -919164.738573  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -902641.612528  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1031764.138245  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -990736.834817  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -976602.864893  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -857247.104794  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -852176.309098  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -851614.666958  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -893320.813807  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -880576.530155  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -880229.241520  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -955874.269428  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -946878.086489  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -958215.656106  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -899533.738999  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -871919.399636  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -867210.225956  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -938785.330270  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -914949.786768  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -900648.062008  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1035148.515356  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -1006400.975727  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -990402.581565  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -850301.425516  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -840577.995830  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -841936.589239  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -883294.399754  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -882166.176474  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -886289.142113  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -963205.511054  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -950594.858441  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -974624.958256  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -888391.006813  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -875658.538829  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -872243.332660  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -928538.357759  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -921351.491491  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -917479.396529  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -1011152.680370  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -985054.352565  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -974149.168685  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -835603.185075  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -832513.385022  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -835561.686162  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -921763.912481  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -917837.742943  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -925414.551910  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -965392.175631  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -970577.856074  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -1001661.411084  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# Minimum root mean squared error: 832513.3850224916
# ---------------------------------------------------
# Train root mean squared error: 199765.16698761558
# Val root mean squared error: 876318.0542109503
# Weight: 0.190
# =========== Set 3 ===========
# Finding best hyper-parameters for the model...
# -1945230.101522  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -1872487.539871  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -1854066.618935  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -2093899.911791  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1972465.411970  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1927057.812393  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2293060.767633  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2200816.061304  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2177411.196005  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -1774951.055796  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -1776438.517914  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -1794358.187980  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1894540.899625  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1862791.857902  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1854065.665633  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2148193.551813  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2090191.018303  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2076036.692153  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -1913383.251155  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -1877857.760121  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -1869475.376575  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -2096333.447761  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2001279.547754  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1962551.553394  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2287080.082201  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2223021.870747  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2193394.241746  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -1836365.605495  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -1840080.111562  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -1831530.158896  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1963206.079527  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1931179.911126  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1930229.193797  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2121308.354544  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2085109.413033  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2072380.513941  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -1958295.630701  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -1958425.027478  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -1965487.384831  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -2085274.198801  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2004797.012392  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1961739.498454  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2273546.732066  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2194329.420756  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2163895.752523  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -1778885.739375  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -1769665.345925  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -1793352.919939  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -1952812.379147  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -1939350.447334  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -1940453.807965  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2143548.496083  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2098053.954975  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2081641.105180  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# Minimum root mean squared error: 1769665.3459252298
# ---------------------------------------------------
# Train root mean squared error: 356579.37136761565
# Val root mean squared error: 1486543.2480352065
# Weight: 0.088
# =========== Set 4 ===========
# Finding best hyper-parameters for the model...
# -2811300.460971  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -2610715.741945  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -2511639.255399  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -3306277.028641  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2999221.133209  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -2797610.894393  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -3577973.172842  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -3242502.876258  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -3031233.817094  with:   {'learning_rate': 0.3, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -2469519.665739  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -2491956.223666  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -2423683.044314  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -2834718.506584  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2632702.609028  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -2577076.377093  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -3076352.633550  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2784515.497860  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2654665.750087  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -2726871.128988  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -2528706.036847  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -2461990.014572  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -3138493.747785  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2851145.778615  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -2697127.451827  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -3462834.159047  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -3138821.234940  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2942045.869418  with:   {'learning_rate': 0.4, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -2559913.538364  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -2560057.805012  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -2649382.911800  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -2776709.596787  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2636609.079247  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -2613688.303968  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2987878.097669  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2764647.174919  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2685750.062124  with:   {'learning_rate': 0.4, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# -2798707.074597  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 150}
# -2660903.265224  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 300}
# -2586233.602629  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 10, 'n_estimators': 500}
# -3068403.345670  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2806441.723439  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 300}
# -2642853.329134  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 50, 'n_estimators': 500}
# -3382820.372627  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 150}
# -3076063.003097  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2884425.458309  with:   {'learning_rate': 0.5, 'max_depth': 2, 'min_samples_leaf': 80, 'n_estimators': 500}
# -2583837.051631  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 150}
# -2595510.931908  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 300}
# -2597655.678861  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# -2772466.946824  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 150}
# -2707521.293938  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
# -2707175.010143  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 500}
# -2839453.332702  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 150}
# -2640612.917374  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 300}
# -2603737.285047  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 80, 'n_estimators': 500}
# Best params set: {'learning_rate': 0.3, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 500}
# Minimum root mean squared error: 2423683.044313918
# ---------------------------------------------------
# Train root mean squared error: 499597.4784581772
# Val root mean squared error: 2348230.08742988
# Weight: 0.046
# ******************************
# Overall train root mean squared error: 197039.7377184425
# Overall val root mean squared error: 697410.4059605828

# %%
# Fine tune model for a specific training subset

save_model = False
training_set = 0     # Choose from 0~4
X_train = bathrooms_train_list[training_set].iloc[:, :-1]
Y_train = bathrooms_train_list[training_set].iloc[:, -1]
samples_weight = len(bathrooms_train_list[training_set]) / len(train_set_copy)

task = GBDT_model()

params = {'learning_rate': 0.6, 
          'max_depth': 4,
          'min_samples_leaf': 10,
          'n_estimators': 300
         }
# {'learning_rate': 0.5, 'max_depth': 4, 'min_samples_leaf': 50, 'n_estimators': 300}
gbdt_reg, _, _ = task.build_model(X_train, Y_train, params, grid_search=False)

if save_model:
    save_path = "Models/Bathrooms_models/gbdt_bathrooms_" + str(training_set) + ".pkl"
    joblib.dump(gbdt_reg, save_path)

print("Weight: %.3f" % samples_weight)
# Out:
# Train root mean squared error: 76152.00742569627
# Val root mean squared error: 208500.5911121237
# Weight: 0.255

# %% [markdown]
# ## Xgboost

# %%
class XGBoost_model():
    def __init__(self, **kwargs):
        self.objective = kwargs.get('objective', 'reg:squarederror')
        self.learning_rate = kwargs.get('learning_rate', 0.15)
        self.subsample = kwargs.get('subsample', 1.0)
        self.max_depth = kwargs.get('max_depth', 3)
        self.n_estimators = kwargs.get('n_estimators', 150)
        self.booster = kwargs.get('booster', 'gbtree')
        self.gamma = kwargs.get('gamma', 0)
        self.reg_alpha = kwargs.get('reg_alpha', 0)
        self.reg_lambda = kwargs.get('reg_lambda', 1)

    def opt_hyper_grid(self, x, y, param_space, num_sets: int=5):

        print('Finding best hyper-parameters for the model...')
        estimator = xgb.XGBRegressor(objective=self.objective, max_depth=self.max_depth,
                                     learning_rate=self.learning_rate, n_estimators=self.n_estimators,
                                     subsample=self.subsample, booster=self.booster, n_jobs=-1, gamma=self.gamma,
                                     reg_alpha=self.reg_alpha, reg_lambda=self.reg_lambda)
        xgb_try = GridSearchCV(estimator=estimator, param_grid=param_space, cv=KFold(n_splits=num_sets, shuffle=True), scoring='neg_root_mean_squared_error')
        grid_result = xgb_try.fit(x, y)

        means = grid_result.cv_results_['mean_test_score']
        params = grid_result.cv_results_['params']
        
        for mean, param in zip(means, params):
            print("%f  with:   %r" % (mean, param))

        best_params = xgb_try.best_params_
        print('Best params set:', best_params)
        print('Minimum root mean squared error: ', -np.max(means))
        print('---------------------------------------------------')
        
        self.learning_rate = best_params.get('learning_rate', self.learning_rate)
        self.max_depth = best_params.get('max_depth', self.max_depth)
        self.subsample = best_params.get('subsample', self.subsample)
        self.n_estimators = best_params.get('n_estimators', self.n_estimators)
        self.booster = best_params.get('booster', self.booster)
        self.gamma = best_params.get('gamma', self.gamma)
        self.reg_alpha = best_params.get('reg_alpha', self.reg_alpha)
        self.reg_lambda = best_params.get('alpha', self.reg_lambda)

        return 


    def build_model(self, x, y, params, grid_search: bool = True):
        """
        If use grid search, then each parameter can have multiple values
        
        Example: params = {'learning_rate': [0.1, 0.3],
                           'n_estimators': [100, 200, 300]
                           }
                           
        If do not use grid search, then each parameter should have only one value
        
        Example: params = {'learning_rate': 0.1,
                           'n_estimators': 100
                          }
        
        """
        
        
        if grid_search:
            self.opt_hyper_grid(x, y, params)
        else:

            self.learning_rate = params.get('learning_rate', self.learning_rate)
            self.max_depth = params.get('max_depth', self.max_depth)
            self.subsample = params.get('subsample', self.subsample)
            self.n_estimators = params.get('n_estimators', self.n_estimators)
            self.booster = params.get('booster', self.booster)
            self.gamma = params.get('gamma', self.gamma)
            self.reg_alpha = params.get('reg_alpha', self.reg_alpha)
            self.reg_lambda = params.get('alpha', self.reg_lambda)

        xgb_reg = xgb.XGBRegressor(objective=self.objective, max_depth=self.max_depth,
                                   learning_rate=self.learning_rate, n_estimators=self.n_estimators,
                                   subsample=self.subsample, booster=self.booster, gamma=self.gamma,
                                   n_jobs=-1, reg_alpha=self.reg_alpha, reg_lambda=self.reg_lambda)
        
        # 10-folder cross validation
        sk = KFold(n_splits=5, shuffle=True)
        scores_train = list()
        scores_val = list()
        for train_ind, val_ind in sk.split(x, y):
            train_x = x.iloc[train_ind].values
            train_y = y.iloc[train_ind]
            val_x = x.iloc[val_ind].values
            val_y = y.iloc[val_ind]

            xgb_reg.fit(train_x, train_y)
            pred_train_xgb = xgb_reg.predict(train_x)
            pred_val_xgb = xgb_reg.predict(val_x)

            score_train = mean_squared_error(train_y, pred_train_xgb, squared=False)
            scores_train.append(score_train)
            score_val = mean_squared_error(val_y, pred_val_xgb, squared=False)
            scores_val.append(score_val)

        print('Train root mean squared error:', np.mean(scores_train))
        print('Val root mean squared error:', np.mean(scores_val))

        return xgb_reg, np.mean(scores_train), np.mean(scores_val)

# %%
# Grid search hyperparameters for each model
train_error = 0
val_error = 0
save_model = True


for i in range(len(bathrooms_train_list)):
    print("=========== Set %d ===========" % i)
    samples_weight = len(bathrooms_train_list[i]) / len(train_set_copy)
    X_train = bathrooms_train_list[i].iloc[:, :-1]
    X_train['no_of_units'] = X_train['no_of_units'].astype('float32')
    Y_train = bathrooms_train_list[i].iloc[:, -1]
    
    task = XGBoost_model()

    params = {'learning_rate': [0.3, 0.5, 0.7],
              'n_estimators': [150, 300, 400, 600],
              'max_depth':[3, 4, 5]

    }

    xgb_reg, scores_train, scores_val = task.build_model(X_train, Y_train, params, grid_search=True)
    if save_model:
        save_path = "Models/Bathrooms_models/xgboost_bathrooms_" + str(i) + ".pkl"
        joblib.dump(xgb_reg, save_path)

    print("Weight: %.3f" % samples_weight)
    train_error += scores_train * samples_weight
    val_error += scores_val * samples_weight

print("*" * 30)
print("Overall train root mean squared error: %.10f" % train_error)
print("Overall val root mean squared error: %.10f" % val_error)
# kaggle_X_test = X_test_plus_auxiliary_data
# Out:
# =========== Set 0 ===========
# Finding best hyper-parameters for the model...
# -227465.956050  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -220542.086023  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -219054.081633  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 400}
# -217223.976064  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 600}
# -225922.242208  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -222844.511486  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -222117.622980  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 400}
# -222085.656084  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 600}
# -226260.870721  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -225675.197019  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -225608.423222  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 400}
# -225907.169197  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 600}
# -236326.933498  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 150}
# -233060.592262  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 300}
# -232021.167238  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 400}
# -231532.771779  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 600}
# -229929.091587  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150}
# -228949.654251  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 300}
# -229104.574624  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 400}
# -229423.790955  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 600}
# -246382.647963  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 150}
# -246325.372130  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 300}
# -246554.491986  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 400}
# -246757.051272  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 600}
# -242480.471824  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -240749.285738  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -240170.520259  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 400}
# -239474.282269  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 600}
# -256922.458070  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -257154.292595  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -256606.439955  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 400}
# -256799.600153  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 600}
# -264098.750832  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -264469.923828  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -264997.747933  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 400}
# -265180.254772  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 600}
# Best params set: {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 600}
# Minimum root mean squared error:  217223.97606383878
# ---------------------------------------------------
# Train root mean squared error: 81942.52935594373
# Val root mean squared error: 259191.57685228786
# Weight: 0.255
# =========== Set 1 ===========
# Finding best hyper-parameters for the model...
# -670008.361985  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -654639.148534  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -650922.232255  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 400}
# -647191.382754  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 600}
# -672026.258733  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -662511.284796  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -661255.865349  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 400}
# -661253.821930  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 600}
# -661273.346036  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -657667.275450  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -657740.171525  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 400}
# -657709.013854  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 600}
# -650252.670270  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 150}
# -637147.541676  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 300}
# -636184.400740  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 400}
# -633455.800836  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 600}
# -662626.226955  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150}
# -657142.684418  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 300}
# -655827.342976  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 400}
# -655889.083844  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 600}
# -671272.946451  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 150}
# -671592.767586  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 300}
# -671938.246305  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 400}
# -672223.537835  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 600}
# -671373.552282  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -663031.459676  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -662110.370735  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 400}
# -660854.428841  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 600}
# -676923.095233  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -674405.477550  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -673419.646221  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 400}
# -674753.941034  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 600}
# -643710.618265  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -643068.882649  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -643277.678866  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 400}
# -643771.146974  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 600}
# Best params set: {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 600}
# Minimum root mean squared error:  633455.8008355766
# ---------------------------------------------------
# Train root mean squared error: 138821.65556282902
# Val root mean squared error: 630971.8950976916
# Weight: 0.421
# =========== Set 2 ===========
# Finding best hyper-parameters for the model...
# -805746.995517  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -786676.488279  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -781772.067756  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 400}
# -777953.286713  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 600}
# -792802.686629  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -784339.564823  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -782991.915603  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 400}
# -782904.009223  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 600}
# -765263.092623  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -764509.350102  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -765566.585493  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 400}
# -767078.839969  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 600}
# -869557.228122  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 150}
# -859240.532446  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 300}
# -860151.845149  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 400}
# -861455.542267  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 600}
# -806014.155577  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150}
# -803513.498270  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 300}
# -804491.452804  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 400}
# -805761.150517  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 600}
# -816837.904309  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 150}
# -818268.089637  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 300}
# -818931.688114  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 400}
# -820130.449673  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 600}
# -817411.339111  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -809009.538271  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -808407.883717  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 400}
# -807780.836585  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 600}
# -804472.364566  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -803734.295205  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -804232.256303  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 400}
# -806436.197040  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 600}
# -786853.944471  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -788982.939169  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -789704.193690  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 400}
# -790200.708804  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 600}
# Best params set: {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# Minimum root mean squared error:  764509.3501016159
# ---------------------------------------------------
# Train root mean squared error: 154064.4036811387
# Val root mean squared error: 812820.1905826012
# Weight: 0.190
# =========== Set 3 ===========
# Finding best hyper-parameters for the model...
# -1512437.747866  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -1483366.652021  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -1482549.492068  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 400}
# -1481246.677030  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 600}
# -1460709.409636  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -1459427.905343  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -1462097.938239  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 400}
# -1462525.098473  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 600}
# -1492550.692358  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -1491455.459496  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -1491980.378731  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 400}
# -1492683.152051  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 600}
# -1552956.542424  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 150}
# -1558595.625477  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 300}
# -1560350.915085  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 400}
# -1564147.092303  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 600}
# -1583944.485165  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150}
# -1584950.719142  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 300}
# -1585744.115339  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 400}
# -1586040.437432  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 600}
# -1583986.372252  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 150}
# -1583087.095049  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 300}
# -1583348.013698  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 400}
# -1583708.635646  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 600}
# -1640359.752318  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -1641526.082349  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -1645520.298330  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 400}
# -1644487.090811  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 600}
# -1720865.823051  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -1720655.572143  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -1720269.660922  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 400}
# -1719836.746877  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 600}
# -1631152.020469  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -1631899.738821  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -1632034.256950  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 400}
# -1632058.272122  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 600}
# Best params set: {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# Minimum root mean squared error:  1459427.9053431696
# ---------------------------------------------------
# Train root mean squared error: 332096.33889855543
# Val root mean squared error: 1513686.276163164
# Weight: 0.088
# =========== Set 4 ===========
# Finding best hyper-parameters for the model...
# -2567978.520334  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 150}
# -2564129.476158  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# -2574340.135392  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 400}
# -2586970.068386  with:   {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 600}
# -2671015.514438  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 150}
# -2680810.068391  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 300}
# -2688098.798502  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 400}
# -2695539.232835  with:   {'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 600}
# -2547038.849931  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# -2557559.295142  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 300}
# -2558969.973906  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 400}
# -2560334.874277  with:   {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 600}
# -2594094.664171  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 150}
# -2595981.412418  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 300}
# -2598388.753397  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 400}
# -2603200.442430  with:   {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 600}
# -2671910.703159  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150}
# -2682992.314809  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 300}
# -2682826.045379  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 400}
# -2683574.110049  with:   {'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 600}
# -2645489.246653  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 150}
# -2649833.552991  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 300}
# -2650072.199215  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 400}
# -2650206.988436  with:   {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 600}
# -2840200.568905  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 150}
# -2842250.371306  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 300}
# -2849227.912869  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 400}
# -2858951.403824  with:   {'learning_rate': 0.7, 'max_depth': 3, 'n_estimators': 600}
# -2851312.011550  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 150}
# -2850631.311170  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 300}
# -2850768.306125  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 400}
# -2852049.733449  with:   {'learning_rate': 0.7, 'max_depth': 4, 'n_estimators': 600}
# -2755649.819645  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 150}
# -2756757.765897  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 300}
# -2756825.645823  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 400}
# -2756831.565033  with:   {'learning_rate': 0.7, 'max_depth': 5, 'n_estimators': 600}
# Best params set: {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 150}
# Minimum root mean squared error:  2547038.8499314287
# ---------------------------------------------------
# Train root mean squared error: 403932.7151010832
# Val root mean squared error: 2964094.6326248352
# Weight: 0.046
# ******************************
# Overall train root mean squared error: 156419.1568575005
# Overall val root mean squared error: 755692.3868372890

# %%
# Fine tune model for a specific training subset

save_model = False
training_set = 1      # Choose from 0~4

X_train = bathrooms_train_list[training_set].iloc[:, :-1]
X_train['no_of_units'] = X_train['no_of_units'].astype('float32')
Y_train = bathrooms_train_list[training_set].iloc[:, -1]

samples_weight = len(bathrooms_train_list[training_set]) / len(train_set_copy)

task = XGBoost_model()

params = {'learning_rate': 0.6, 
          'n_estimators': 500,
          'max_depth': 3
}


xgb_reg, _, _ = task.build_model(X_train, Y_train, params, grid_search=False)

if save_model:
    save_path = "Models/Bathrooms_models/xgboost_bathrooms_" + str(training_set) + ".pkl"
    joblib.dump(xgb_reg, save_path)

print("Weight: %.3f" % samples_weight)
# Out:
# Train root mean squared error: 140110.82086521326
# Val root mean squared error: 625396.5344912794
# Weight: 0.421

# %% [markdown]
# ## LightGBM

# %%
class LightGBM_model():
    def __init__(self, **kwargs):
        self.boosting_type = kwargs.get('boosting_type', 'gbdt')
        self.num_leaves = kwargs.get('num_leaves', 16)
        self.learning_rate = kwargs.get('learning_rate', 0.15)
        self.subsample = kwargs.get('subsample', 1.0)
        self.subsample_for_bin = kwargs.get('subsample_for_bin', 200000)
        self.max_depth = kwargs.get('max_depth', 3)
        self.n_estimators = kwargs.get('n_estimators', 150)
        self.min_split_gain = kwargs.get('min_split_gain', 0.0)
        self.min_child_samples = kwargs.get('min_child_samples', 20)
        self.reg_alpha = kwargs.get('reg_alpha', 0)
        self.reg_lambda = kwargs.get('reg_lambda', 1)
        

    def opt_hyper_grid(self, x, y, param_space, num_sets: int=5):

        print('Finding best hyper-parameters for the model...')
        estimator = lgb.LGBMRegressor(boosting_type=self.boosting_type, num_leaves=self.num_leaves, 
                                      max_depth=self.max_depth, learning_rate=self.learning_rate, 
                                      n_estimators=self.n_estimators, subsample_for_bin=self.subsample_for_bin, 
                                      min_split_gain=self.min_split_gain, min_child_samples=self.min_child_samples, 
                                      subsample=self.subsample, reg_alpha=self.reg_alpha, 
                                      reg_lambda=self.reg_lambda, n_jobs=-1)
        lgb_try = GridSearchCV(estimator=estimator, 
                               param_grid=param_space, 
                               cv=KFold(n_splits=num_sets, shuffle=True), 
                               scoring='neg_root_mean_squared_error')
        grid_result = lgb_try.fit(x, y)

        means = grid_result.cv_results_['mean_test_score']
        params = grid_result.cv_results_['params']
        
        for mean, param in zip(means, params):
            print("%f  with:   %r" % (mean, param))

        best_params = lgb_try.best_params_
        print('Best params set:', best_params)
        print('Minimum root mean squared error:', -np.max(means))
        print('---------------------------------------------------')
        self.boosting_type = best_params.get('boosting_type', self.boosting_type)
        self.num_leaves = best_params.get('num_leaves', self.num_leaves)
        self.learning_rate = best_params.get('learning_rate', self.learning_rate)
        self.subsample = best_params.get('subsample', self.subsample)
        self.subsample_for_bin = best_params.get('subsample_for_bin', self.subsample_for_bin)
        self.max_depth = best_params.get('max_depth', self.max_depth)
        self.n_estimators = best_params.get('n_estimators', self.n_estimators)
        self.min_split_gain = best_params.get('min_split_gain', self.min_split_gain)
        self.min_child_samples = best_params.get('min_child_samples', self.min_child_samples)
        self.reg_alpha = best_params.get('reg_alpha', self.reg_alpha)
        self.reg_lambda = best_params.get('reg_lambda', self.reg_lambda)

        return 


    def build_model(self, x, y, params, grid_search: bool = True):
        """
        If use grid search, then each parameter can have multiple values
        
        Example: params = {'learning_rate': [0.1, 0.3],
                           'n_estimators': [100, 200, 300]
                           }
                           
        If do not use grid search, then each parameter should have only one value
        
        Example: params = {'learning_rate': 0.1,
                           'n_estimators': 100
                          }
        
        """
        
        
        if grid_search:
            self.opt_hyper_grid(x, y, params)
        else:

            self.boosting_type = params.get('boosting_type', self.boosting_type)
            self.num_leaves = params.get('num_leaves', self.num_leaves)
            self.learning_rate = params.get('learning_rate', self.learning_rate)
            self.subsample = params.get('subsample', self.subsample)
            self.subsample_for_bin = params.get('subsample_for_bin', self.subsample_for_bin)
            self.max_depth = params.get('max_depth', self.max_depth)
            self.n_estimators = params.get('n_estimators', self.n_estimators)
            self.min_split_gain = params.get('min_split_gain', self.min_split_gain)
            self.min_child_samples = params.get('min_child_samples', self.min_child_samples)
            self.reg_alpha = params.get('reg_alpha', self.reg_alpha)
            self.reg_lambda = params.get('reg_lambda', self.reg_lambda)

        lgb_reg = lgb.LGBMRegressor(boosting_type=self.boosting_type, num_leaves=self.num_leaves, 
                                      max_depth=self.max_depth, learning_rate=self.learning_rate, 
                                      n_estimators=self.n_estimators, subsample_for_bin=self.subsample_for_bin, 
                                      min_split_gain=self.min_split_gain, min_child_samples=self.min_child_samples, 
                                      subsample=self.subsample, reg_alpha=self.reg_alpha, 
                                      reg_lambda=self.reg_lambda, n_jobs=- 1)
        # 10-folder cross validation
        sk = KFold(n_splits=5, shuffle=True)
        scores_train = list()
        scores_val = list()
        for train_ind, val_ind in sk.split(x, y):
            train_x = x.iloc[train_ind].values
            train_y = y.iloc[train_ind]
            val_x = x.iloc[val_ind].values
            val_y = y.iloc[val_ind]

            lgb_reg.fit(train_x, train_y)
            pred_train_lgb = lgb_reg.predict(train_x)
            pred_val_lgb = lgb_reg.predict(val_x)

            score_train = mean_squared_error(train_y, pred_train_lgb, squared=False)
            scores_train.append(score_train)
            score_val = mean_squared_error(val_y, pred_val_lgb, squared=False)
            scores_val.append(score_val)

        print('Train root mean squared error:', np.mean(scores_train))
        print('Val root mean squared error:', np.mean(scores_val))

        return lgb_reg, np.mean(scores_train), np.mean(scores_val)

# %%
train_error = 0
val_error = 0
save_model = True

for i in range(len(bathrooms_train_list)):
    print("=========== Set %d ===========" % i)
    samples_weight = len(bathrooms_train_list[i]) / len(train_set_copy)
    X_train = bathrooms_train_list[i].iloc[:, :-1]
    Y_train = bathrooms_train_list[i].iloc[:, -1]
    
    task = LightGBM_model()

    params = {
        'learning_rate': [0.3, 0.5, 0.7],
        'n_estimators': [200, 300, 500],
        'max_depth':[3, 4],
        'min_child_samples': [10, 30, 50],
        'num_leaves': [16, 32]
    }

    lgb_reg, scores_train, scores_val = task.build_model(X_train, Y_train, params, grid_search=True)
    if save_model:
        save_path = "Models/Bathrooms_models/lightgbm_bathrooms_" + str(i) + ".pkl"
        joblib.dump(lgb_reg, save_path)

    print("Weight: %.3f" % samples_weight)
    train_error += scores_train * samples_weight
    val_error += scores_val * samples_weight

print("*" * 30)
print("Overall train root mean squared error: %.10f" % train_error)
print("Overall val root mean squared error: %.10f" % val_error)
# kaggle_X_test = X_test_plus_auxiliary_data
# Out:
# =========== Set 0 ===========
# Finding best hyper-parameters for the model...
# -220428.302146  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -220428.302146  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -215367.145184  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -215367.145184  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -210591.276876  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -210591.276876  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -250184.721896  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -250184.721896  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -241963.981136  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -241963.981136  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -234349.942201  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -234349.942201  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -259432.895107  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -259432.895107  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -250456.662472  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -250456.662472  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -242671.998371  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -242671.998371  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -210336.644675  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -210336.644675  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -207148.713032  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -207148.713032  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -204851.069247  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -204851.069247  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -241874.438693  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -241874.438693  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -233901.398732  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -233901.398732  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -225893.144742  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -225893.144742  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -253509.235916  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -253509.235916  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -244250.004460  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -244250.004460  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -237253.636468  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -237253.636468  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -218587.861130  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -218587.861130  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -215432.578382  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -215432.578382  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -212258.820620  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -212258.820620  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -243092.238630  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -243092.238630  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -237205.292832  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -237205.292832  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -232375.423769  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -232375.423769  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -254511.770230  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -254511.770230  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -247849.258257  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -247849.258257  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -241489.713063  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -241489.713063  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -213716.634433  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -213716.634433  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -212439.679760  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -212439.679760  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -211319.868290  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -211319.868290  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -244739.021573  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -244739.021573  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -240702.760681  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -240702.760681  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -237693.297353  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -237693.297353  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -249627.721023  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -249627.721023  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -245239.904261  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -245239.904261  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -242258.923530  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -242258.923530  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -213378.702829  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -213378.702829  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -210876.392001  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -210876.392001  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -208921.249938  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -208921.249938  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -249236.413401  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -249236.413401  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -246597.556125  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -246597.556125  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -242909.921526  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -242909.921526  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -245381.248966  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -245381.248966  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -242896.229201  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -242896.229201  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -238721.304320  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -238721.304320  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -217138.355832  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -217138.355832  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -216334.689737  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -216334.689737  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -216167.854061  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -216167.854061  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -250051.112806  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -250051.112806  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -249008.251774  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -249008.251774  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -246674.968549  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -246674.968549  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -241596.030592  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -241596.030592  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -239567.686808  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -239567.686808  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -239596.243312  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -239596.243312  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# Minimum root mean squared error: 204851.06924676674
# ---------------------------------------------------
# Train root mean squared error: 76577.89369851975
# Val root mean squared error: 203268.98265477383
# Weight: 0.255
# =========== Set 1 ===========
# Finding best hyper-parameters for the model...
# -583852.973890  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -583852.973890  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -566460.290664  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -566460.290664  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -550261.951328  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -550261.951328  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -969355.418595  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -969355.418595  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -930738.514416  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -930738.514416  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -901921.340768  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -901921.340768  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1136788.061745  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1136788.061745  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1093144.518504  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1093144.518504  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1065453.933918  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1065453.933918  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -536335.328589  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -536335.328589  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -519547.275276  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -519547.275276  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -509046.223767  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -509046.223767  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -935420.614019  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -935420.614019  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -896837.410994  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -896837.410994  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -879622.633304  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -879622.633304  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1083219.332811  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1083219.332811  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1049434.410264  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1049434.410264  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1031297.884765  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1031297.884765  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -576187.535166  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -576187.535166  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -566470.107644  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -566470.107644  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -559095.707897  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -559095.707897  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -898582.060826  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -898582.060826  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -872696.414528  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -872696.414528  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -859398.376883  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -859398.376883  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1104275.226037  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1104275.226037  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1076022.786895  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1076022.786895  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1067416.014118  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1067416.014118  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -533056.757064  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -533056.757064  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -527294.450655  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -527294.450655  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -523394.849072  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -523394.849072  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -893923.734146  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -893923.734146  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -890793.855006  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -890793.855006  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -898400.203231  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -898400.203231  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1059646.765337  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1059646.765337  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1041121.653754  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1041121.653754  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1041490.101801  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1041490.101801  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -557732.021519  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -557732.021519  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -551101.055516  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -551101.055516  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -551558.159582  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -551558.159582  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -951716.349659  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -951716.349659  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -942425.949790  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -942425.949790  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -930206.680351  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -930206.680351  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1096692.825792  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1096692.825792  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1085432.399521  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1085432.399521  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1080934.846823  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1080934.846823  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -567904.827588  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -567904.827588  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -565900.649938  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -565900.649938  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -562453.248344  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -562453.248344  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -932939.649749  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -932939.649749  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -926740.434474  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -926740.434474  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -924522.202703  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -924522.202703  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1103611.061447  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1103611.061447  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1095993.129233  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1095993.129233  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1109018.907319  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1109018.907319  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# Minimum root mean squared error: 509046.22376693244
# ---------------------------------------------------
# Train root mean squared error: 173562.1717747334
# Val root mean squared error: 671199.8676749173
# Weight: 0.421
# =========== Set 2 ===========
# Finding best hyper-parameters for the model...
# -854072.877344  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -854072.877344  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -855224.000405  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -855224.000405  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -848636.098094  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -848636.098094  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -852423.798837  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -852423.798837  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -853135.376406  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -853135.376406  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -856712.859341  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -856712.859341  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -909174.233909  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -909174.233909  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -896525.295761  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -896525.295761  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -890787.120547  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -890787.120547  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -883800.570100  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -883800.570100  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -883234.889832  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -883234.889832  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -882774.740726  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -882774.740726  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -858751.235341  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -858751.235341  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -866766.775579  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -866766.775579  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -881216.510816  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -881216.510816  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -890419.928488  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -890419.928488  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -882906.696438  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -882906.696438  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -884104.356905  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -884104.356905  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -910132.713469  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -910132.713469  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -908069.576306  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -908069.576306  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -907565.894572  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -907565.894572  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -884443.393893  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -884443.393893  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -884660.777715  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -884660.777715  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -883571.542998  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -883571.542998  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -888777.906390  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -888777.906390  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -874374.379571  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -874374.379571  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -878173.854054  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -878173.854054  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -896465.300869  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -896465.300869  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -895232.331814  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -895232.331814  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -899374.760850  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -899374.760850  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -873360.823456  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -873360.823456  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -886220.069115  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -886220.069115  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -893449.235386  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -893449.235386  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -908484.160136  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -908484.160136  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -908341.965254  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -908341.965254  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -920286.722731  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -920286.722731  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -885990.073764  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -885990.073764  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -880062.838841  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -880062.838841  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -876399.637122  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -876399.637122  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -918912.279996  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -918912.279996  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -915149.176529  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -915149.176529  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -921798.009699  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -921798.009699  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -922308.420978  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -922308.420978  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -926364.394012  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -926364.394012  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -923060.671358  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -923060.671358  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -889064.837131  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -889064.837131  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -887575.747697  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -887575.747697  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -888151.172640  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -888151.172640  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -927072.926953  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -927072.926953  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -931793.815275  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -931793.815275  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -935190.142147  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -935190.142147  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -924807.770432  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -924807.770432  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -941557.809283  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -941557.809283  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -951841.543857  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -951841.543857  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# Minimum root mean squared error: 848636.0980942091
# ---------------------------------------------------
# Train root mean squared error: 259651.1065135422
# Val root mean squared error: 790035.9875489955
# Weight: 0.190
# =========== Set 3 ===========
# Finding best hyper-parameters for the model...
# -1584256.029846  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -1584256.029846  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -1568755.859383  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -1568755.859383  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -1556784.541715  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -1556784.541715  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -1858378.071732  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -1858378.071732  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -1846296.407372  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -1846296.407372  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -1827289.795843  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -1827289.795843  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1938809.231652  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1938809.231652  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1917183.712955  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1917183.712955  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1913347.464898  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1913347.464898  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -1566949.358726  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -1566949.358726  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -1558833.247966  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -1558833.247966  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -1561849.725405  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -1561849.725405  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -1898771.322276  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -1898771.322276  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -1885311.624935  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -1885311.624935  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -1883524.620608  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -1883524.620608  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -1950425.151399  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -1950425.151399  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -1946493.914206  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -1946493.914206  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -1957305.990647  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -1957305.990647  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -1533433.481749  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -1533433.481749  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -1522634.933633  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -1522634.933633  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -1520383.349688  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -1520383.349688  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -1905723.229252  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# ...
# -1929146.773070  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -1929146.773070  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -1928387.252961  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -1928387.252961  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2064650.089928  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2064650.089928  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2053925.045340  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2053925.045340  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2039202.509588  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2039202.509588  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# Minimum root mean squared error: 1520383.3496882445
# ---------------------------------------------------
# Train root mean squared error: 378814.7683970889
# Val root mean squared error: 1731006.241919497
# Weight: 0.088
# =========== Set 4 ===========
# Finding best hyper-parameters for the model...
# -2603624.544716  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -2603624.544716  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -2586703.468123  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -2586703.468123  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -2568620.521757  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -2568620.521757  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -2697904.815564  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -2697904.815564  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -2648488.686221  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -2648488.686221  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -2612818.191141  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -2612818.191141  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2739832.326902  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2739832.326902  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2674242.233969  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2674242.233969  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2599011.497139  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2599011.497139  with:   {'learning_rate': 0.3, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -2503355.238365  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -2503355.238365  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -2493112.135902  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -2493112.135902  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -2484410.299481  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -2484410.299481  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -2701461.928093  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -2701461.928093  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -2669652.237299  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -2669652.237299  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -2659293.270694  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -2659293.270694  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2691209.878689  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2691209.878689  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2614098.924734  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2614098.924734  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2574832.062910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2574832.062910  with:   {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -2520989.357442  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -2520989.357442  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -2504624.128311  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -2504624.128311  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -2506533.890828  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -2506533.890828  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -2607201.938480  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -2607201.938480  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -2574648.171757  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -2574648.171757  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -2556114.349159  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -2556114.349159  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2734085.404212  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2734085.404212  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2694103.733862  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2694103.733862  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2643936.026111  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2643936.026111  with:   {'learning_rate': 0.5, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -2606164.362777  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -2606164.362777  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -2609634.975429  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -2609634.975429  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -2617929.683830  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -2617929.683830  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -2680157.726714  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -2680157.726714  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -2661039.304162  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -2661039.304162  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -2657604.641317  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -2657604.641317  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2678717.648738  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2678717.648738  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2664409.845054  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2664409.845054  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2660542.417246  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2660542.417246  with:   {'learning_rate': 0.5, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -2779900.429950  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -2779900.429950  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -2763911.513390  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -2763911.513390  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -2765127.392470  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -2765127.392470  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -2769679.761913  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -2769679.761913  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -2751868.335741  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -2751868.335741  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -2750330.463446  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -2750330.463446  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2852092.622372  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2852092.622372  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2815564.283677  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2815564.283677  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2783132.916775  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2783132.916775  with:   {'learning_rate': 0.7, 'max_depth': 3, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# -2688172.521953  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 16}
# -2688172.521953  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 200, 'num_leaves': 32}
# -2698701.736275  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 16}
# -2698701.736275  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 300, 'num_leaves': 32}
# -2709260.036565  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# -2709260.036565  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 32}
# -2711706.109980  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 16}
# -2711706.109980  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 200, 'num_leaves': 32}
# -2695988.275592  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 16}
# -2695988.275592  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 300, 'num_leaves': 32}
# -2702967.489254  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 16}
# -2702967.489254  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 30, 'n_estimators': 500, 'num_leaves': 32}
# -2768671.216859  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 16}
# -2768671.216859  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 200, 'num_leaves': 32}
# -2760666.788763  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 16}
# -2760666.788763  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 300, 'num_leaves': 32}
# -2753006.622541  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 16}
# -2753006.622541  with:   {'learning_rate': 0.7, 'max_depth': 4, 'min_child_samples': 50, 'n_estimators': 500, 'num_leaves': 32}
# Best params set: {'learning_rate': 0.3, 'max_depth': 4, 'min_child_samples': 10, 'n_estimators': 500, 'num_leaves': 16}
# Minimum root mean squared error: 2484410.299481187
# ---------------------------------------------------
# Train root mean squared error: 486182.9872798429
# Val root mean squared error: 2601240.5917063346
# Weight: 0.046
# ******************************
# Overall train root mean squared error: 197649.2072441445
# Overall val root mean squared error: 756540.9569215681

# %%
save_model = False
training_set = 2      # Choose from 0~4
X_train = bathrooms_train_list[training_set].iloc[:, :-1]
Y_train = bathrooms_train_list[training_set].iloc[:, -1]
samples_weight = len(bathrooms_train_list[training_set]) / len(train_set_copy)

task = LightGBM_model()

params = {'learning_rate': 0.3, 
          'max_depth': 3,
          'min_child_samples': 10,
          'n_estimators': 500,
          'num_leaves': 10 }


lgb_reg, _, _ = task.build_model(X_train, Y_train, params, grid_search=False)

if save_model:
    save_path = "Models/Bathrooms_models/lightgbm_bathrooms_" + str(training_set) + ".pkl"
    joblib.dump(lgb_reg, save_path)

print("Weight: %.3f" % samples_weight)
# Out:
# Train root mean squared error: 254240.6179090223
# Val root mean squared error: 898470.6522058524
# Weight: 0.190

# %% [markdown]
# ## Test with Kaggle test set

# %%
# Import test dataset
data_type = {
            'listing_id': int,
            'name': str,
             'street': str,
             'type': str,
             'model': str,
             'market_segment': str,
             'type_of_area': str,
             'bedrooms': str,
             'bathrooms': float,
             'district': int,
             'region': str,
             'planning_area': str,
             'subszone': str,
             'lat': float,
             'lng': float,
             'tenure': str,
             'built_year': float,
             'no_of_units': float,
             'area_size': float,
             'eco_category': str,
             'accessibility': str,
             'date_listed': str
             }

test_set = pd.read_csv("Data/test.csv", dtype=data_type)


# Make a copy
test_set_copy = test_set.copy()

test_set_copy.head(3)

# Check nan for each column
for col_name, _ in test_set_copy.iteritems():
    if len(test_set_copy[test_set_copy[col_name].isna()])>0:
        print("%s: %s rows" % (col_name, len(test_set_copy[test_set_copy[col_name].isna()])))
# Out:
# model: 388 rows
# bedrooms: 118 rows
# bathrooms: 337 rows
# tenure: 85 rows
# built_year: 2875 rows
# no_of_units: 326 rows

# %%
def convert_test_set(X_test):
    # Data preprocessing for test data set
    
    #transformaing bedrooms, i.e: from 2+1 to 3
    X_test['bedrooms']=X_test['bedrooms'].apply(lambda x: x if type(x)==float else eval(x))
    
    # Deal with NaN data
    X_test['bedrooms'].fillna(value=bedroom_median, inplace=True)
    X_test['bathrooms'].fillna(value=bathroom_median, inplace=True)
    X_test['built_year'].fillna(value=built_year_median, inplace=True)
    X_test['no_of_units'].fillna(value=no_of_units_median, inplace=True)

    # Check column 'tenure', treat houses that are not 'freehold' as 'leasehold', also fill NaN with 'leasehold'
    X_test['tenure'].where(X_test['tenure']=='freehold', other='leasehold', inplace=True)

    # Drop rows whose area_size is NaN
    X_test.dropna(axis=0, subset=['area_size'], inplace=True)
    
    # Convert some string columns to 0-1 verctors
    # Type
    type_mapping = {'apartment': 0 ,'condominium' : 1}
    X_test['type'] = X_test['type'].map(type_mapping)
    # Tenure
    tenure_mapping = {'freehold':0 ,'leasehold' : 1}
    X_test['tenure'] = X_test['tenure'].map(tenure_mapping)
    
    # For 'build_year', use 2022 - original year to get current age of houses
    X_test['built_year'] = 2022 - X_test['built_year']

    # For no_of_units, divide all houses into 10 categories, manually set lowest limit=0 and highest limit=10000
    X_test['no_of_units'] = pd.cut(X_test['no_of_units'], bins=cut_bins, labels=cut_labels, include_lowest=True).values
    
    # Convert name, street, region and planning area to numerical values
    X_test['name'] = X_test['name'].map(name_mapping)
    X_test['street'] = X_test['street'].map(street_mapping)
    X_test['region'] = X_test['region'].map(region_mapping)
    X_test['planning_area'] = X_test['planning_area'].map(planning_area_mapping)


    return

# %%
convert_test_set(test_set_copy)
test_set_copy.reset_index(drop=True, inplace=True)
test_set_copy.head(3)
# Out:
#    listing_id    name  street  type        model market_segment type_of_area  \
# 0     1487111    11.0   305.0     1  condominium            ocr       strata
# 1     6794066   119.0  1428.0     1  condominium            ocr       strata
# 2     4027017  1572.0   828.0     0    apartment            ocr       strata
#
#    bedrooms  bathrooms  district  ...      subszone       lat         lng  \
# 0       2.0        2.0        10  ...  farrer court  1.313566  103.803218
# 1       3.0        2.0        15  ...   tanjong rhu  1.298437  103.884408
# 2       3.0        1.0        15  ...       frankel  1.317851  103.908905
#
#    tenure  built_year  no_of_units  area_size   eco_category  accessibility  \
# 0       0         8.0        630.0      710.0  uncategorized        guarded
# 1       0         6.0        138.5     1055.0  uncategorized        guarded
# 2       0         9.0        138.5      463.0  uncategorized        guarded
#
#   date_listed
# 0  2021-12-12
# 1  2021-10-12
# 2  2021-12-23
#
# [3 rows x 22 columns]

# %%
test_distance = cal_distance(test_set_copy, is_train=False)
test_distance.reset_index(drop=True, inplace=True)

# %%
# Option 1: Test set without "distance" information
# X_test_without_auxiliary_data = test_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'lat', 'lng', 'tenure', 'built_year', 'no_of_units', 'area_size']]
X_test_without_auxiliary_data = test_set_copy[['type', 'bedrooms', 'bathrooms', 'district', 'tenure', 'built_year', 'no_of_units', 'area_size']]
X_test_without_auxiliary_data.head(3)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       2.0        2.0        10       0         8.0       630.0
# 1     1       3.0        2.0        15       0         6.0       138.5
# 2     0       3.0        1.0        15       0         9.0       138.5
#
#    area_size
# 0      710.0
# 1     1055.0
# 2      463.0

# %%
# Option 2: Test set with "distance" information
X_test_plus_auxiliary_data = pd.concat([X_test_without_auxiliary_data, test_distance], axis=1)
# X_test_plus_auxiliary_data = pd.concat([X_test_without_auxiliary_data, test_distance[['to_primary_schools', 'to_secondary_schools']]], axis=1)
X_test_plus_auxiliary_data.head(3)
# Out:
#    type  bedrooms  bathrooms  district  tenure  built_year no_of_units  \
# 0     1       2.0        2.0        10       0         8.0       630.0
# 1     1       3.0        2.0        15       0         6.0       138.5
# 2     0       3.0        1.0        15       0         9.0       138.5
#
#    area_size  to_commercial_centres  to_hawker_centres  to_primary_schools  \
# 0      710.0               1.659712           0.410398            0.980559
# 1     1055.0               2.415213           0.446516            1.469982
# 2      463.0               1.712861           0.587265            0.893951
#
#    to_secondary_schools  to_shopping_malls  to_train_stations
# 0              1.048619           1.128913           0.654270
# 1              0.249159           0.969806           0.888254
# 2              1.343460           1.475109           0.572349

# %%
model_dict = {
    0: "gbdt",
    1: "xgboost",
    2: "lightgbm"

}

model_index = 1
model_root_path = "Models/Bathrooms_models/" + model_dict[model_index]

bathrooms_model_0 = joblib.load(model_root_path + "_bathrooms_0.pkl")
bathrooms_model_1 = joblib.load(model_root_path + "_bathrooms_1.pkl")
bathrooms_model_2 = joblib.load(model_root_path + "_bathrooms_2.pkl")
bathrooms_model_3 = joblib.load(model_root_path + "_bathrooms_3.pkl")
bathrooms_model_4 = joblib.load(model_root_path + "_bathrooms_4.pkl")

kaggle_Y_pred = np.zeros(shape=(len(X_test_plus_auxiliary_data),))
bathrooms_split_points = [1, 2, 3, 4, 5]
bathroom_models = [bathrooms_model_0, bathrooms_model_1, bathrooms_model_2, bathrooms_model_3, bathrooms_model_4]

for i in range(len(X_test_plus_auxiliary_data)):
    sample_input = X_test_plus_auxiliary_data.iloc[i,:]
    sample_bathroom = sample_input['bathrooms']
    sample_input = sample_input.values.reshape(1, -1)
    
    
    isFound = False
    for j in range(len(bathroom_models)-2):
        if bathrooms_split_points[j] <= sample_bathroom < bathrooms_split_points[j+1]:
            kaggle_Y_pred[i] = bathroom_models[j].predict(sample_input)
            isFound = True
            break
    if not isFound:
        kaggle_Y_pred[i] = bathroom_models[-1].predict(sample_input)

# %%
kaggle_Y_pred
# Out:
# array([1982394.875, 2580773.25 ,  766586.125, ..., 1677901.625,
#         948555.375, 7901041.   ])

# %%
pred_df = pd.Series(kaggle_Y_pred, name='Predicted')
# print(len(pred_df)) 

# Save the results
sava_root_path = "Results/Bathrooms_model_results/" + model_dict[model_index] + "_"
pred_df.to_csv(sava_root_path + "gs_with_aux.csv", header=['Predicted'], index_label=['Id'])
